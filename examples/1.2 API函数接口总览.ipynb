# %% [markdown]
# ## 1. OKX API接口说明
#
# ```python
# from okx.api import API
# ```
#
# ## 2. 交易账户 Account
#
# ```python
# from okx.api import Account
# ```
#
# |方法|解释|Path|
# |:---|:---|:---|
# |get_balance|查看账户余额|/api/v5/account/balance|
# |get_positions|查看持仓信息|/api/v5/account/positions|
# |get_positions_history|查看历史持仓信息|/api/v5/account/positions-history|
# |get_account_position_risk|查看账户持仓风险|/api/v5/account/account-position-risk|
# |get_bills|账单流水查询（近七天）|/api/v5/account/bills|
# |get_bills_archive|账单流水查询（近三月）|/api/v5/account/bills-archive|
# |get_config|查看账户配置|/api/v5/account/config|
# |set_position_mode|设置持仓模式|/api/v5/account/set-position-mode|
# |set_leverage|设置杠杆倍数|/api/v5/account/set-leverage|
# |get_max_size|获取最大可买卖/开仓数量|/api/v5/account/max-size|
# |get_max_avail_size|获取最大可用数量|/api/v5/account/max-avail-size|
# |set_margin_balance|调整保证金|/api/v5/account/position/margin-balance|
# |get_leverage_info|获取杠杆倍数|/api/v5/account/leverage-info|
# |get_adjust_leverage_info|获取杠杆倍数预估信息|/api/v5/account/adjust-leverage-info|
# |get_max_loan|获取交易产品最大可借|/api/v5/account/max-loan|
# |get_trade_fee|获取当前账户交易手续费费率|/api/v5/account/trade-fee|
# |get_interest_accrued|获取计息记录|/api/v5/account/interest-accrued|
# |get_interest_rate|获取用户当前市场借币利率|/api/v5/account/interest-rate|
# |set_greeks|期权greeks的PA/BS切换|/api/v5/account/set-greeks|
# |set_isolated_mode|逐仓交易设置|/api/v5/account/set-isolated-mode|
# |get_max_withdrawal|查看账户最大可转余额|/api/v5/account/max-withdrawal|
# |get_risk_state|查看账户特定风险状态|/api/v5/account/risk-state|
# |set_quick_margin_borrow_repay|一键借币模式手动借币还币|/api/v5/account/quick-margin-borrow-repay|
# |get_quick_margin_borrow_repay_history|获取一键借币还币历史|/api/v5/account/quick-margin-borrow-repay-history|
# |set_borrow_repay|尊享借币还币|/api/v5/account/borrow-repay|
# |get_borrow_repay_history|获取尊享借币还币历史|/api/v5/account/borrow-repay-history|
# |get_vip_interest_accrued|获取尊享借币计息记录|/api/v5/account/vip-interest-accrued|
# |get_vip_interest_deducted|获取尊享借币扣息记录|/api/v5/account/vip-interest-deducted|
# |get_vip_loan_order_list|尊享借币订单列表|/api/v5/account/vip-loan-order-list|
# |get_vip_loan_order_detail|尊享借币订单详情|/api/v5/account/vip-loan-order-detail|
# |get_interest_limits|获取借币利率与限额|/api/v5/account/interest-limits|
# |set_simulated_margin|组合保证金的虚拟持仓保证金计算|/api/v5/account/simulated_margin|
# |get_greeks|查看账户Greeks|/api/v5/account/greeks|
# |get_position_tiers|获取组合保证金模式仓位限制|/api/v5/account/position-tiers|
# |set_riskOffset_type|设置组合保证金账户风险对冲模式|/api/v5/account/set-riskOffset-type|
# |set_activate_option|开通期权交易|/api/v5/account/activate-option|
# |set_auto_loan|设置自动借币|/api/v5/account/set-auto-loan|
# |set_account_level|设置账户模式|/api/v5/account/set-account-level|
# |set_mmp_reset|重置 MMP 状态|/api/v5/account/mmp-reset|
# |set_mmp_config|设置 MMP|/api/v5/account/mmp-config|
# |get_mmp_config|查看 MMP 配置|/api/v5/account/mmp-config|
#
# ## 3. 交易 Trade
#
# ```python
# from okx.api import Trade
# ```
#
# |方法|解释|Path|
# |:---|:---|:---|
# |set_order|下单|/api/v5/trade/order|
# |set_batch_orders|批量下单|/api/v5/trade/batch-orders|
# |set_cancel_order|撤单|/api/v5/trade/cancel-order|
# |set_cancel_batch_orders|批量撤单|/api/v5/trade/cancel-batch-orders|
# |set_amend_order|修改订单|/api/v5/trade/amend-order|
# |set_amend_batch_orders|批量修改订单|/api/v5/trade/amend-batch-orders|
# |set_close_position|市价仓位全平|/api/v5/trade/close-position|
# |get_order|获取订单信息|/api/v5/trade/order|
# |get_orders_pending|获取未成交订单列表|/api/v5/trade/orders-pending|
# |get_orders_history|获取历史订单记录（近七天）|/api/v5/trade/orders-history|
# |get_orders_history_archive|获取历史订单记录（近三个月）|/api/v5/trade/orders-history-archive|
# |get_fills|获取成交明细（近三天）|/api/v5/trade/fills|
# |get_fills_history|获取成交明细（近三个月）|/api/v5/trade/fills-history|
# |set_fills_archive|申请成交明细（近两年）|/api/v5/trade/fills-archive|
# |get_fills_archive|获取成交明细（近两年）|/api/v5/trade/fills-archive|
# |get_easy_convert_currency_list|获取一键兑换主流币币种列表|/api/v5/trade/easy-convert-currency-list|
# |set_easy_convert|一键兑换主流币交易|/api/v5/trade/easy-convert|
# |get_easy_convert_history|获取一键兑换主流币历史记录|/api/v5/trade/easy-convert-history|
# |get_one_click_repay_currency_list|获取一键还债币种列表|/api/v5/trade/one-click-repay-currency-list|
# |set_one_click_repay|一键还债交易|/api/v5/trade/one-click-repay|
# |get_one_click_repay_history|获取一键还债历史记录|/api/v5/trade/one-click-repay-history|
# |set_mass_cancel|撤销 MMP 订单|/api/v5/trade/mass-cancel|
# |set_cancel_all_after|倒计时全部撤单|/api/v5/trade/cancel-all-after|
#
# ## 4. 策略交易 AlgoTrade
#
# ```python
# from okx.api import AlgoTrade
# ```
#
# |方法|解释|Path|
# |:---|:---|:---|
# |set_order_algo|策略委托下单|/api/v5/trade/order-algo|
# |set_cancel_algos|撤销策略委托订单|/api/v5/trade/cancel-algos|
# |set_amend_algos|修改策略委托订单|/api/v5/trade/amend-algos|
# |set_cancel_advance_algos|撤销高级策略委托订单|/api/v5/trade/cancel-advance-algos|
# |get_order_algo|获取策略委托单信息|/api/v5/trade/order-algo|
# |get_orders_algo_pending|获取未完成策略委托单列表|/api/v5/trade/orders-algo-pending|
# |get_orders_algo_history|获取历史策略委托单列表|/api/v5/trade/orders-algo-history|
#
# ## 5. 网格交易 GridTrade
#
# ```python
# from okx.api import GridTrade
# ```
#
# |方法|解释|Path|
# |:---|:---|:---|
# |set_order_algo|网格策略委托下单|/api/v5/tradingBot/grid/order-algo|
# |set_amend_order_algo|修改网格策略订单|/api/v5/tradingBot/grid/amend-order-algo|
# |set_stop_order_algo|网格策略停止|/api/v5/tradingBot/grid/stop-order-algo|
# |set_close_position|合约网格平仓|/api/v5/tradingBot/grid/close-position|
# |set_cancel_close_order|撤销合约网格平仓单|/api/v5/tradingBot/grid/cancel-close-order|
# |set_order_instant_trigger|网格策略立即触发|/api/v5/tradingBot/grid/order-instant-trigger|
# |get_orders_algo_pending|获取未完成网格策略委托单列表|/api/v5/tradingBot/grid/orders-algo-pending|
# |get_orders_algo_history|获取历史网格策略委托单列表|/api/v5/tradingBot/grid/orders-algo-history|
# |get_orders_algo_details|获取网格策略委托订单详情|/api/v5/tradingBot/grid/orders-algo-details|
# |get_sub_orders|获取网格策略委托子订单信息|/api/v5/tradingBot/grid/sub-orders|
# |get_positions|获取网格策略委托持仓|/api/v5/tradingBot/grid/positions|
# |set_withdraw_income|现货/天地网格提取利润|/api/v5/tradingBot/grid/withdraw-income|
# |set_compute_margin_balance|调整保证金计算|/api/v5/tradingBot/grid/compute-margin-balance|
# |set_margin_balance|调整保证金|/api/v5/tradingBot/grid/margin-balance|
# |get_ai_param|网格策略智能回测（公共）|/api/v5/tradingBot/grid/ai-param|
# |set_min_investment|计算最小投资数量（公共）|/api/v5/tradingBot/grid/min-investment|
# |get_rsi_back_testing|RSI回测（公共）|/api/v5/tradingBot/public/rsi-back-testing|
#
# ## 6. 信号交易 SignalBotTrade
#
# ```python
# from okx.api import SignalBotTrade
# ```
#
# |方法|解释|Path|
# |:---|:---|:---|
# |get_orders_algo_details|获取信号策略详情|/api/v5/tradingBot/signal/orders-algo-details|
# |get_positions|获取信号策略持仓|/api/v5/tradingBot/grid/positions|
# |get_sub_orders|获取信号策略子订单信息|/api/v5/tradingBot/signal/sub-orders|
# |get_event_history|获取信号策略历史事件|/api/v5/tradingBot/signal/event-history|
#
# ## 7. 定投 RecurringBuy
#
# ```python
# from okx.api import RecurringBuy
# ```
#
# |方法|解释|Path|
# |:---|:---|:---|
# |set_order_algo|定投策略委托下单|/api/v5/tradingBot/recurring/order-algo|
# |set_amend_order_algo|修改定投策略订单|/api/v5/tradingBot/recurring/amend-order-algo|
# |set_stop_order_algo|定投策略停止|/api/v5/tradingBot/recurring/stop-order-algo|
# |get_orders_algo_pending|获取未完成定投策略委托单列表|/api/v5/tradingBot/recurring/orders-algo-pending|
# |get_orders_algo_history|获取历史定投策略委托单列表|/api/v5/tradingBot/recurring/orders-algo-history|
# |get_orders_algo_details|获取定投策略委托订单详情|/api/v5/tradingBot/recurring/orders-algo-details|
# |get_sub_orders|获取定投策略子订单信息|/api/v5/tradingBot/recurring/sub-orders|
#
# ## 8. 跟单 CopyTrade
#
# ```python
# from okx.api import CopyTrade
# ```
#
# |方法|解释|Path|
# |:---|:---|:---|
# |get_current_subpositions|交易员获取当前带单|/api/v5/copytrading/current-subpositions|
# |get_subpositions_history|交易员获取历史带单|/api/v5/copytrading/subpositions-history|
# |set_algo_order|交易员止盈止损|/api/v5/copytrading/algo-order|
# |set_close_subposition|交易员平仓|/api/v5/copytrading/close-subposition|
# |get_instruments|交易员获取带单合约|/api/v5/copytrading/instruments|
# |set_instruments|交易员修改带单合约|/api/v5/copytrading/set-instruments|
# |get_profit_sharing_details|交易员历史分润明细|/api/v5/copytrading/profit-sharing-details|
# |get_total_profit_sharing|交易员历史分润汇总|/api/v5/copytrading/total-profit-sharing|
# |get_unrealized_profit_sharing_details|交易员待分润明细|/api/v5/copytrading/unrealized-profit-sharing-details|
#
# ## 9. 行情数据 Market
#
# ```python
# from okx.api import Market
# ```
#
# |方法|解释|Path|
# |:---|:---|:---|
# |get_tickers|获取所有产品行情信息|/api/v5/market/tickers|
# |get_ticker|获取单个产品行情信息|/api/v5/market/ticker|
# |get_books|获取产品深度|/api/v5/market/books|
# |get_books_lite|获取产品轻量深度|/api/v5/market/books-lite|
# |get_candles|获取交易产品K线数据|/api/v5/market/candles|
# |get_history_candles|获取交易产品历史K线数据|/api/v5/market/history-candles|
# |get_trades|获取交易产品公共成交数据|/api/v5/market/trades|
# |get_history_trades|获取交易产品公共历史成交数据|/api/v5/market/history-trades|
# |get_instrument_family_trades|获取期权品种公共成交数据|/api/v5/market/option/instrument-family-trades|
# |get_option_trades|获取期权公共成交数据|/api/v5/public/option-trades|
# |get_platform_24_volume|获取平台24小时总成交量|/api/v5/market/platform-24-volume|
#
# ## 10. 大宗交易 BlockTrade
#
# ```python
# from okx.api import BlockTrade
# ```
#
# |方法|解释|Path|
# |:---|:---|:---|
# |get_counterparties|获取报价方信息|/api/v5/rfq/counterparties|
# |set_create_rfq|询价|/api/v5/rfq/create-rfq|
# |set_cancel_rfq|取消询价单|/api/v5/rfq/cancel-rfq|
# |set_cancel_batch_rfqs|批量取消询价单|/api/v5/rfq/cancel-batch-rfqs|
# |set_cancel_all_rfqs|取消所有询价单|/api/v5/rfq/cancel-all-rfqs|
# |set_execute_quote|执行报价|/api/v5/rfq/execute-quote|
# |get_maker_instrument_settings|获取可报价产品|/api/v5/rfq/maker-instrument-settings|
# |set_maker_instrument_settings|设置可报价产品|/api/v5/rfq/maker-instrument-settings|
# |set_mmp_reset|重设MMP状态|/api/v5/rfq/mmp-reset|
# |set_create_quote|报价|/api/v5/rfq/create-quote|
# |set_cancel_quote|取消报价单|/api/v5/rfq/cancel-quote|
# |set_cancel_batch_quotes|批量取消报价单|/api/v5/rfq/cancel-batch-quotes|
# |set_cancel_all_quotes|取消所有报价单|/api/v5/rfq/cancel-all-quotes|
# |get_rfqs|获取询价单信息|/api/v5/rfq/rfqs|
# |get_quotes|获取报价单信息|/api/v5/rfq/quotes|
# |get_trades|获取大宗交易信息|/api/v5/rfq/trades|
# |get_public_trades|获取大宗交易公共成交数据|/api/v5/rfq/public-trades|
# |get_block_tickers|获取大宗交易所有产品行情信息|/api/v5/market/block-tickers|
# |get_block_ticker|获取大宗交易单个产品行情信息|/api/v5/market/block-ticker|
# |get_block_trades|获取大宗交易公共成交数据|/api/v5/market/block-trades|
#
# ## 11. 价差交易 SpreadTrade
#
# ```python
# from okx.api import SpreadTrade
# ```
#
# |方法|解释|Path|
# |:---|:---|:---|
# |set_order|下单|/api/v5/sprd/order|
# |set_cancel_order|撤单|/api/v5/sprd/cancel-order|
# |set_mass_cancel|全部撤单|/api/v5/sprd/mass-cancel|
# |get_order|获取订单信息|/api/v5/sprd/order|
# |get_orders_pending|获取未成交订单列表|/api/v5/sprd/orders-pending|
# |get_orders_history|获取历史订单记录（近七天)|/api/v5/sprd/orders-history|
# |get_trades|获取历史成交数据（近七天）|/api/v5/sprd/trades|
# |get_spreads|获取Spreads（公共）|/api/v5/sprd/spreads|
# |get_books|获取Spread产品深度（公共）|/api/v5/sprd/books|
# |get_ticker|获取单个Spread产品行情信息（公共）|/api/v5/sprd/ticker|
# |get_public_trades|获取公共成交数据（公共）|/api/v5/sprd/public-trades|
#
# ## 12. 公共数据 Public
#
# ```python
# from okx.api import Public
# ```
#
# |方法|解释|Path|
# |:---|:---|:---|
# |get_instruments|获取交易产品基础信息|/api/v5/public/instruments|
# |get_delivery_exercise_history|获取交割和行权记录|/api/v5/public/delivery-exercise-history|
# |get_open_interest|获取持仓总量|/api/v5/public/open-interest|
# |get_funding_rate|获取永续合约当前资金费率|/api/v5/public/funding-rate|
# |get_funding_rate_history|获取永续合约历史资金费率|/api/v5/public/funding-rate-history|
# |get_price_limit|获取限价|/api/v5/public/price-limit|
# |get_opt_summary|获取期权定价|/api/v5/public/opt-summary|
# |get_estimated_price|获取预估交割/行权价格|/api/v5/public/estimated-price|
# |get_discount_rate_interest_free_quota|获取免息额度和币种折算率等级|/api/v5/public/discount-rate-interest-free-quota|
# |get_time|获取系统时间|/api/v5/public/time|
# |get_mark_price|获取标记价格|/api/v5/public/mark-price|
# |get_position_tiers|获取衍生品仓位档位|/api/v5/public/position-tiers|
# |get_interest_rate_loan_quota|获取市场借币杠杆利率和借币限额|/api/v5/public/interest-rate-loan-quota|
# |get_vip_interest_rate_loan_quota|获取尊享借币杠杆利率和借币限额|/api/v5/public/vip-interest-rate-loan-quota|
# |get_underlying|获取衍生品标的指数|/api/v5/public/underlying|
# |get_insurance_fund|获取风险准备金余额|/api/v5/public/insurance-fund|
# |get_convert_contract_coin|张币转换|/api/v5/public/convert-contract-coin|
# |get_instrument_tick_bands|获取期权价格梯度|/api/v5/public/instrument-tick-bands|
# |get_index_tickers|获取指数行情|/api/v5/market/index-tickers|
# |get_index_candles|获取指数K线数据|/api/v5/market/index-candles|
# |get_history_index_candles|获取指数历史K线数据|/api/v5/market/history-index-candles|
# |get_mark_price_candles|获取标记价格K线数据|/api/v5/market/mark-price-candles|
# |get_history_mark_price_candles|获取标记价格历史K线数据|/api/v5/market/history-mark-price-candles|
# |get_open_oracle|Oracle 上链交易数据|/api/v5/market/open-oracle|
# |get_exchange_rate|获取法币汇率|/api/v5/market/exchange-rate|
# |get_index_components|获取指数成分数据|/api/v5/market/index-components|
#
# ## 13. 交易大数据 TradingStatistics
#
# ```python
# from okx.api import TradingStatistics
# ```
#
# |方法|解释|Path|
# |:---|:---|:---|
# |get_support_coin|获取交易大数据支持币种|/api/v5/rubik/stat/trading-data/support-coin|
# |get_taker_volume|获取主动买入/卖出情况|/api/v5/rubik/stat/taker-volume|
# |get_loan_ratio|获取杠杆多空比|/api/v5/rubik/stat/margin/loan-ratio|
# |get_long_short_account_ratio|获取合约多空持仓人数比|/api/v5/rubik/stat/contracts/long-short-account-ratio|
# |get_contracts_open_interest_volume|获取合约持仓量及交易量|/api/v5/rubik/stat/contracts/open-interest-volume|
# |get_option_open_interest_volume|获取期权持仓量及交易量|/api/v5/rubik/stat/option/open-interest-volume|
# |get_open_interest_volume_ratio|看涨/看跌期权合约 持仓总量比/交易总量比|/api/v5/rubik/stat/option/open-interest-volume-ratio|
# |get_open_interest_volume_expiry|看涨看跌持仓总量及交易总量（按到期日分）|/api/v5/rubik/stat/option/open-interest-volume-expiry|
# |get_open_interest_volume_strike|看涨看跌持仓总量及交易总量（按执行价格分）|/api/v5/rubik/stat/option/open-interest-volume-strike|
# |get_taker_block_volume|看跌/看涨期权合约 主动买入/卖出量|/api/v5/rubik/stat/option/taker-block-volume|
#
# ## 14. 资金账户 FundingAccount
#
# ```python
# from okx.api import FundingAccount
# ```
#
# |方法|解释|Path|
# |:---|:---|:---|
# |get_assert_currencies|获取币种列表|/api/v5/asset/currencies|
# |get_balances|获取资金账户余额|/api/v5/asset/balances|
# |get_non_tradable_assets|获取不可交易资产|/api/v5/asset/non-tradable-assets|
# |get_asset_valuation|获取账户资产估值|/api/v5/asset/asset-valuation|
# |set_transfer|资金划转|/api/v5/asset/transfer|
# |get_transfer_state|获取资金划转状态|/api/v5/asset/transfer-state|
# |get_bills|获取资金流水|/api/v5/asset/bills|
# |get_deposit_lightning|闪电网络充币|/api/v5/asset/deposit-lightning|
# |get_deposit_address|获取充值地址信息|/api/v5/asset/deposit-address|
# |get_deposit_history|获取充值记录|/api/v5/asset/deposit-history|
# |set_withdrawal|提币|/api/v5/asset/withdrawal|
# |set_withdrawal_lightning|闪电网络提币|/api/v5/asset/withdrawal-lightning|
# |set_cancel_withdrawal|撤销提币|/api/v5/asset/cancel-withdrawal|
# |get_withdrawal_history|获取提币记录|/api/v5/asset/withdrawal-history|
# |get_deposit_withdraw_status|获取充值/提现的详细状态|/api/v5/asset/deposit-withdraw-status|
# |set_convert_dust_assets|小额资产兑换|/api/v5/asset/convert-dust-assets|
# |get_exchange_list|获取交易所列表（公共）|/api/v5/asset/exchange-list|
# |get_convert_currencies|获取闪兑币种列表|/api/v5/asset/convert/currencies|
# |get_currency_pair|获取闪兑币对信息|/api/v5/asset/convert/currency-pair|
# |set_estimate_quote|闪兑预估询价|/api/v5/asset/convert/estimate-quote|
# |set_trade|闪兑交易|/api/v5/asset/convert/trade|
# |get_history|获取闪兑交易历史|/api/v5/asset/convert/history|
#
# ## 15. 子账户 SubAccount
#
# ```python
# from okx.api import SubAccount
# ```
#
# |方法|解释|Path|
# |:---|:---|:---|
# |get_list|查看子账户列表|/api/v5/users/subaccount/list|
# |set_modify_apikey|重置子账户的APIKey|/api/v5/users/subaccount/modify-apikey|
# |get_account_balances|获取子账户交易账户余额|/api/v5/account/subaccount/balances|
# |get_assert_balances|获取子账户资金账户余额|/api/v5/asset/subaccount/balances|
# |get_max_withdrawal|获取子账户最大可转余额|/api/v5/account/subaccount/max-withdrawal|
# |get_bills|查询子账户转账记录|/api/v5/asset/subaccount/bills|
# |get_managed_subaccount_bills|查询托管子账户转账记录|/api/v5/asset/subaccount/managed-subaccount-bills|
# |set_transfer|子账户间资金划转|/api/v5/asset/subaccount/transfer|
# |set_transfer_out|设置子账户主动转出权限|/api/v5/users/subaccount/set-transfer-out|
# |get_entrust_subaccount_list|查看被托管的子账户列表|/api/v5/users/entrust-subaccount-list|
# |get_if_rebate|获取用户的节点返佣信息|/api/v5/users/partner/if-rebate|
# |set_loan_allocation|设置子账户尊享借币比率|/api/v5/account/subaccount/set-loan-allocation|
# |get_interest_limits|获取子账户借币利率与限额|/api/v5/account/subaccount/interest-limits|
#
# ## 16. 赚币 Earn
#
# ```python
# from okx.api import Earn
# ```
#
# |方法|解释|Path|
# |:---|:---|:---|
# |get_offers|查看项目|/api/v5/finance/staking-defi/offers|
# |set_purchase|申购项目|/api/v5/finance/staking-defi/purchase|
# |set_redeem|赎回项目|/api/v5/finance/staking-defi/redeem|
# |set_cancel|撤销项目申购/赎回|/api/v5/finance/staking-defi/cancel|
# |get_orders_active|查看活跃订单|/api/v5/finance/staking-defi/orders-active|
# |get_orders_history|查看历史订单|/api/v5/finance/staking-defi/orders-history|
#
# ## 17. 余币宝 Savings
#
# ```python
# from okx.api import savings
# ```
#
# |方法|解释|Path|
# |:---|:---|:---|
# |get_balance|获取余币宝余额|/api/v5/finance/savings/balance|
# |set_purchase_redempt|余币宝申购/赎回|/api/v5/finance/savings/purchase-redempt|
# |set_lending_rate|设置余币宝借贷利率|/api/v5/finance/savings/set-lending-rate|
# |get_lending_history|获取余币宝出借明细|/api/v5/finance/savings/lending-history|
# |get_lending_rate_summary|获取市场借贷信息（公共）|/api/v5/finance/savings/lending-rate-summary|
# |get_lending_rate_history|获取市场借贷历史（公共）|/api/v5/finance/savings/lending-rate-history|
#
# ## 18. 系统 Status
#
# ```python
# from okx.api import Status
# ```
#
# |方法|解释|Path|
# |:---|:---|:---|
# |get_status|获取系统升级事件的状态|/api/v5/system/status|

# %% [markdown]
# ## 1. APP 现货交易-市单价平仓函数总览

# %% [markdown]
# |方法|解释|
# |:---|:---|
# |close_market|市价单卖出|

# %% [markdown]
# ## 2. 模型实例化

# %%
from okx.app import OkxSPOT
from pprint import pprint

# %%
# 现货交易账户需要秘钥
key = "xxx"
secret = "xxx"
passphrase = "xxx"
# 实盘：0，虚拟盘：1
flag = '0'
# 使用http和https代理，proxies={'http':'xxxxx','https:':'xxxxx'}，与requests中的proxies参数规则相同
proxies = {}
# 转发：需搭建转发服务器，可参考：https://github.com/pyted/okx_resender
proxy_host = None

okxSPOT = OkxSPOT(
    key=key, secret=secret, passphrase=passphrase, proxies=proxies, proxy_host=proxy_host,
)
trade = okxSPOT.trade

# %% [markdown]
# ## 3. 同步 市价平仓（卖出）

# %%
close_market3 = trade.close_market(
    instId='MANA-USDT',  # 产品
    quantity='10',  # 平仓数量 
    tag='',  # 订单标签
    clOrdId='',  # 客户自定义订单ID
    meta={},  # 向回调函数中传递的参数字典
)

pprint(close_market3)
# Out:
# {'cancel_result': None,
#  'error_result': None,
#  'func_param': {'callback': None,
#                 'cancel': True,
#                 'clOrdId': '',
#                 'delay': 0.2,
#                 'errorback': None,
#                 'instId': 'MANA-USDT',
#                 'meta': {},
#                 'newThread': False,
#                 'quantity': '10',
#                 'tag': '',
#                 'timeout': 60},
#  'get_order_result': {'code': '0',
#                       'data': {'accFillSz': '10',
#                                'algoClOrdId': '',
#                                'algoId': '',
#                                'attachAlgoClOrdId': '',
#                                'attachAlgoOrds': [],
#                                'avgPx': '0.4563',
#                                'cTime': '1706422418915',
#                                'cancelSource': '',
#                                'cancelSourceReason': '',
#                                'category': 'normal',
#                                'ccy': '',
#                                'clOrdId': '',
#                                'fee': '-0.004563',
#                                'feeCcy': 'USDT',
#                                'fillPx': '0.4563',
#                                'fillSz': '10',
#                                'fillTime': '1706422418919',
#                                'instId': 'MANA-USDT',
#                                'instType': 'SPOT',
#                                'lever': '',
#                                'ordId': '671719542657552399',
#                                'ordType': 'market',
#                                'pnl': '0',
#                                'posSide': 'net',
#                                'px': '',
#                                'pxType': '',
#                                'pxUsd': '',
#                                'pxVol': '',
#                                'quickMgnType': '',
#                                'rebate': '0',
#                                'rebateCcy': 'MANA',
#                                'reduceOnly': 'false',
#                                'side': 'sell',
#                                'slOrdPx': '',
#                                'slTriggerPx': '',
#                                'slTriggerPxType': '',
#                                'source': '',
#                                'state': 'filled',
#                                'stpId': '',
#                                'stpMode': '',
#                                'sz': '10',
#                                'tag': '',
#                                'tdMode': 'cash',
#                                'tgtCcy': 'base_ccy',
#                                'tpOrdPx': '',
#                                'tpTriggerPx': '',
#                                'tpTriggerPxType': '',
#                                'tradeId': '36688623',
#                                'uTime': '1706422418918'},
#                       'msg': ''},
#  'instId': 'MANA-USDT',
#  'instType': 'SPOT',
#  'meta': {},
#  'ordId': '671719542657552399',
#  'request_param': {'clOrdId': '',
#                    'instId': 'MANA-USDT',
#                    'ordType': 'market',
#                    'side': 'sell',
#                    'sz': '10',
#                    'tag': '',
#                    'tdMode': 'cash'},
#  'set_order_result': {'code': '0',
#                       'data': {'clOrdId': '',
#                                'ordId': '671719542657552399',
#                                'sCode': '0',
#                                'sMsg': 'Order placed',
#                                'tag': ''},
#                       'inTime': '1706422418916516',
#                       'msg': '',
#                       'outTime': '1706422418918605'},
#  'state': 'filled'}

# %% [markdown]
# ## 4. 同步 市价平仓（卖出） 回调函数

# %%
# 执行成功回调
def callback4(information):
    print('callback')
    pprint(information)


# 执行错误回调
def errorback4(information):
    print('errorback')
    pprint(information)

# %%
# 设置callback和errorback
close_market4 = okxSPOT.trade.close_market(
    instId='MANA-USDT',  # 产品
    quantity='10',  # 平仓数量  'all' 表示全部可用数量
    tag='',  # 订单标签
    clOrdId='',  # 客户自定义订单ID
    meta={},  # 向回调函数中传递的参数字典

    callback=callback4,  # 开仓成功触发的回调函数
    errorback=errorback4,  # 开仓失败触发的回调函数
)
# Out:
# callback
# {'cancel_result': None,
#  'error_result': None,
#  'func_param': {'callback': <function callback4 at 0x7fd5c8e4d1f0>,
#                 'cancel': True,
#                 'clOrdId': '',
#                 'delay': 0.2,
#                 'errorback': <function errorback4 at 0x7fd5c8e4d310>,
#                 'instId': 'MANA-USDT',
#                 'meta': {},
#                 'newThread': False,
#                 'quantity': '10',
#                 'tag': '',
#                 'timeout': 60},
#  'get_order_result': {'code': '0',
#                       'data': {'accFillSz': '10',
#                                'algoClOrdId': '',
#                                'algoId': '',
#                                'attachAlgoClOrdId': '',
#                                'attachAlgoOrds': [],
#                                'avgPx': '0.456',
#                                'cTime': '1706422463289',
#                                'cancelSource': '',
#                                'cancelSourceReason': '',
#                                'category': 'normal',
#                                'ccy': '',
#                                'clOrdId': '',
#                                'fee': '-0.00456',
#                                'feeCcy': 'USDT',
#                                'fillPx': '0.456',
#                                'fillSz': '10',
#                                'fillTime': '1706422463292',
#                                'instId': 'MANA-USDT',
#                                'instType': 'SPOT',
#                                'lever': '',
#                                'ordId': '671719728775598080',
#                                'ordType': 'market',
#                                'pnl': '0',
#                                'posSide': 'net',
#                                'px': '',
#                                'pxType': '',
#                                'pxUsd': '',
#                                'pxVol': '',
#                                'quickMgnType': '',
#                                'rebate': '0',
#                                'rebateCcy': 'MANA',
#                                'reduceOnly': 'false',
#                                'side': 'sell',
#                                'slOrdPx': '',
#                                'slTriggerPx': '',
#                                'slTriggerPxType': '',
#                                'source': '',
#                                'state': 'filled',
#                                'stpId': '',
#                                'stpMode': '',
#                                'sz': '10',
#                                'tag': '',
#                                'tdMode': 'cash',
#                                'tgtCcy': 'base_ccy',
#                                'tpOrdPx': '',
#                                'tpTriggerPx': '',
#                                'tpTriggerPxType': '',
#                                'tradeId': '36688626',
#                                'uTime': '1706422463291'},
#                       'msg': ''},
#  'instId': 'MANA-USDT',
#  'instType': 'SPOT',
#  'meta': {},
#  'ordId': '671719728775598080',
#  'request_param': {'clOrdId': '',
#                    'instId': 'MANA-USDT',
#                    'ordType': 'market',
#                    'side': 'sell',
#                    'sz': '10',
#                    'tag': '',
#                    'tdMode': 'cash'},
#  'set_order_result': {'code': '0',
#                       'data': {'clOrdId': '',
#                                'ordId': '671719728775598080',
#                                'sCode': '0',
#                                'sMsg': 'Order placed',
#                                'tag': ''},
#                       'inTime': '1706422463289580',
#                       'msg': '',
#                       'outTime': '1706422463291716'},
#  'state': 'filled'}

# %% [markdown]
# ## 5. 异步 市价平仓（卖出）回调函数

# %%
# 执行成功回调
def callback5(information):
    print('thread callback')
    pprint(information)


# 执行错误回调
def errorback5(information):
    print('thread errorback')
    pprint(information)

# %%
# newThread=True
close_market5 = okxSPOT.trade.close_market(
    instId='MANA-USDT',  # 产品
    quantity='10',  # 平仓数量 (交易货币) 'all' 表示全部可用数量
    callback=callback5,  # 开仓成功触发的回调函数
    errorback=errorback5,  # 开仓失败触发的回调函数
    tag='',  # 订单标签
    clOrdId='',  # 客户自定义订单ID
    meta={},  # 向回调函数中传递的参数字典

    newThread=True,  # 是否开启一个新的线程维护这个订单
)

pprint(close_market5)
print('-' * 30)
# Out:
# <Thread(Thread-5, started 123145491202048)>
# ------------------------------
# thread callback
# {'cancel_result': None,
#  'error_result': None,
#  'func_param': {'callback': <function callback5 at 0x7fd5c8e4d670>,
#                 'cancel': True,
#                 'clOrdId': '',
#                 'delay': 0.2,
#                 'errorback': <function errorback5 at 0x7fd5c8e4d430>,
#                 'instId': 'MANA-USDT',
#                 'meta': {},
#                 'newThread': True,
#                 'quantity': '10',
#                 'tag': '',
#                 'timeout': 60},
#  'get_order_result': {'code': '0',
#                       'data': {'accFillSz': '10',
#                                'algoClOrdId': '',
#                                'algoId': '',
#                                'attachAlgoClOrdId': '',
#                                'attachAlgoOrds': [],
#                                'avgPx': '0.4558',
#                                'cTime': '1706422521027',
#                                'cancelSource': '',
#                                'cancelSourceReason': '',
#                                'category': 'normal',
#                                'ccy': '',
#                                'clOrdId': '',
#                                'fee': '-0.004558',
#                                'feeCcy': 'USDT',
#                                'fillPx': '0.4558',
#                                'fillSz': '10',
#                                'fillTime': '1706422521030',
#                                'instId': 'MANA-USDT',
#                                'instType': 'SPOT',
#                                'lever': '',
#                                'ordId': '671719970946322435',
#                                'ordType': 'market',
#                                'pnl': '0',
#                                'posSide': 'net',
#                                'px': '',
#                                'pxType': '',
#                                'pxUsd': '',
#                                'pxVol': '',
#                                'quickMgnType': '',
#                                'rebate': '0',
#                                'rebateCcy': 'MANA',
#                                'reduceOnly': 'false',
#                                'side': 'sell',
#                                'slOrdPx': '',
#                                'slTriggerPx': '',
#                                'slTriggerPxType': '',
#                                'source': '',
#                                'state': 'filled',
#                                'stpId': '',
#                                'stpMode': '',
#                                'sz': '10',
#                                'tag': '',
#                                'tdMode': 'cash',
#                                'tgtCcy': 'base_ccy',
#                                'tpOrdPx': '',
#                                'tpTriggerPx': '',
#                                'tpTriggerPxType': '',
#                                'tradeId': '36688629',
#                                'uTime': '1706422521030'},
#                       'msg': ''},
#  'instId': 'MANA-USDT',
#  'instType': 'SPOT',
#  'meta': {},
#  'ordId': '671719970946322435',
#  'request_param': {'clOrdId': '',
#                    'instId': 'MANA-USDT',
#                    'ordType': 'market',
#                    'side': 'sell',
#                    'sz': '10',
#                    'tag': '',
#                    'tdMode': 'cash'},
#  'set_order_result': {'code': '0',
#                       'data': {'clOrdId': '',
#                                'ordId': '671719970946322435',
#                                'sCode': '0',
#                                'sMsg': 'Order placed',
#                                'tag': ''},
#                       'inTime': '1706422521028671',
#                       'msg': '',
#                       'outTime': '1706422521030409'},
#  'state': 'filled'}

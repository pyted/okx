# %% [markdown]
# ## 1. 永续合约交易账户函数总览

# %% [markdown]
# |方法|解释|
# |:---|:---|
# |get_balance|获取单个货币余额|
# |get_balances|获取全部货币余额（列表格式）|
# |get_balancesMap|获取全部货币余额（字典格式）|
# |set_marginType|设置持仓模式|
# |set_leverage|调整开仓杠杆|
# |get_leverage|获取杠杆倍数|
# |get_position|获取单个产品的持仓信息|
# |get_positions|获取全部产品的持仓信息（列表格式）|
# |get_positionsMap|获取全部产品的持仓信息字典（字典格式）|

# %% [markdown]
# ## 2. 模型实例化

# %%
from okx.app import OkxSWAP
from okx.app.utils import eprint

# %%
# 永续合约交易账户需要秘钥
key = "xxx"
secret = "xxx"
passphrase = "xxx"
# 实盘：0，虚拟盘：1
flag = '0'
# 使用http和https代理，proxies={'http':'xxxxx','https:':'xxxxx'}，与requests中的proxies参数规则相同
proxies = {}
# 转发：需搭建转发服务器，可参考：https://github.com/pyted/okx_resender
proxy_host = None

okxSWAP = OkxSWAP(
    key=key, secret=secret, passphrase=passphrase, proxies=proxies, proxy_host=proxy_host,
)
account = okxSWAP.account
# 如果有挂单或持仓，会提示“设置持仓方式为双向持仓失败”，如果你的持仓模式已经是双向持仓，可以忽略这个警告
# Out:
# [FAILURE] 设置持仓方式为双向持仓失败，请手动设置：posMode="long_short_mode"

# %% [markdown]
# ## 3. 获取单个货币余额 get_balance

# %%
get_balance = okxSWAP.account.get_balance(ccy='USDT')
eprint(get_balance)
# Out:
# {'code': '0',
#  'data': {'adjEq': '',
#           'borrowFroz': '',
#           'details': {'availBal': '45.766495059637',
#                       'availEq': '45.766495059637',
#                       'borrowFroz': '',
#                       'cashBal': '49.936428392970335',
#                       'ccy': 'USDT',
#                       '...': '......'},
#           'imr': '',
#           'isoEq': '9.097727060000002',
#           'mgnRatio': '',
#           'mmr': '',
#           'notionalUsd': '',
#           'ordFroz': '',
#           'totalEq': '101.2655450347435',
#           'uTime': '1706425762136',
#           'upl': ''},
#  'msg': ''}

# %% [markdown]
# ## 4. 获取全部货币余额（列表格式）

# %%
# instIds 产品列表
# ccys 币种列表
# 参数instIds与ccys默认值为[]，如果均为空，表示全部资产
get_balances = account.get_balances()
eprint(get_balances, length=5)
# Out:
# {'code': '0',
#  'data': {'adjEq': '',
#           'borrowFroz': '',
#           'details': [{'availBal': '45.766561726303664',
#                        'availEq': '45.766561726303664',
#                        'borrowFroz': '',
#                        'cashBal': '49.936428392970335',
#                        'ccy': 'USDT',
#                        '...': '......'},
#                       {'availBal': '77.978827031',
#                        'availEq': '77.978827031',
#                        'borrowFroz': '',
#                        'cashBal': '77.978827031',
#                        'ccy': 'MANA',
#                        '...': '......'},
#                       {'availBal': '0.0000999',
#                        'availEq': '0.0000999',
#                        'borrowFroz': '',
#                        'cashBal': '0.0000999',
#                        'ccy': 'BTC',
#                        '...': '......'},
#                       {'availBal': '0.000999',
#                        'availEq': '0.000999',
#                        'borrowFroz': '',
#                        'cashBal': '0.000999',
#                        'ccy': 'ETH',
#                        '...': '......'},
#                       {'availBal': '0.889068985',
#                        'availEq': '0.889068985',
#                        'borrowFroz': '',
#                        'cashBal': '0.889068985',
#                        'ccy': 'IOTA',
#                        '...': '......'},
#                       '......'],
#           'imr': '',
#           'isoEq': '9.097636080000003',
#           'mgnRatio': '',
#           'mmr': '',
#           'notionalUsd': '',
#           'ordFroz': '',
#           'totalEq': '101.26504464245956',
#           'uTime': '1706425763432',
#           'upl': ''},
#  'msg': ''}

# %%
# 获取BTC和ETH的资产
get_balances = account.get_balances(instIds=['BTC-USDT', 'ETH-USDT'])
eprint(get_balances, length=10)
# Out:
# {'code': '0',
#  'data': {'adjEq': '',
#           'borrowFroz': '',
#           'details': [{'availBal': '0.0000999',
#                        'availEq': '0.0000999',
#                        'borrowFroz': '',
#                        'cashBal': '0.0000999',
#                        'ccy': 'BTC',
#                        'crossLiab': '',
#                        'disEq': '4.2365292299999995',
#                        'eq': '0.0000999',
#                        'eqUsd': '4.2365292299999995',
#                        'fixedBal': '0',
#                        'frozenBal': '0',
#                        'imr': '0',
#                        'interest': '',
#                        'isoEq': '0',
#                        'isoLiab': '',
#                        'isoUpl': '0',
#                        'liab': '',
#                        'maxLoan': '',
#                        'mgnRatio': '',
#                        'mmr': '0',
#                        'notionalLever': '0',
#                        'ordFrozen': '0',
#                        'spotInUseAmt': '',
#                        'spotIsoBal': '0',
#                        'stgyEq': '0',
#                        'twap': '0',
#                        'uTime': '1706351191880',
#                        'upl': '0',
#                        'uplLiab': ''},
#                       {'availBal': '0.000999',
#                        'availEq': '0.000999',
#                        'borrowFroz': '',
#                        'cashBal': '0.000999',
#                        'ccy': 'ETH',
#                        'crossLiab': '',
#                        'disEq': '2.28652119',
#                        'eq': '0.000999',
#                        'eqUsd': '2.28652119',
#                        'fixedBal': '0',
#                        'frozenBal': '0',
#                        'imr': '0',
#                        'interest': '',
#                        'isoEq': '0',
#                        'isoLiab': '',
#                        'isoUpl': '0',
#                        'liab': '',
#                        'maxLoan': '',
#                        'mgnRatio': '',
#                        'mmr': '0',
#                        'notionalLever': '0',
#                        'ordFrozen': '0',
#                        'spotInUseAmt': '',
#                        'spotIsoBal': '0',
#                        'stgyEq': '0',
#                        'twap': '0',
#                        'uTime': '1706351152974',
#                        'upl': '0',
#                        'uplLiab': ''}],
#           'imr': '',
#           'isoEq': '9.097636080000003',
#           'mgnRatio': '',
#           'mmr': '',
#           'notionalUsd': '',
#           'ordFroz': '',
#           'totalEq': '101.26514463845956',
#           'uTime': '1706425763726',
#           'upl': ''},
#  'msg': ''}

# %%
# 获取BTC和ETH的资产
get_balances = account.get_balances(ccys=['BTC', 'ETH'])
eprint(get_balances, length=10)
# Out:
# {'code': '0',
#  'data': {'adjEq': '',
#           'borrowFroz': '',
#           'details': [{'availBal': '0.0000999',
#                        'availEq': '0.0000999',
#                        'borrowFroz': '',
#                        'cashBal': '0.0000999',
#                        'ccy': 'BTC',
#                        'crossLiab': '',
#                        'disEq': '4.2365292299999995',
#                        'eq': '0.0000999',
#                        'eqUsd': '4.2365292299999995',
#                        'fixedBal': '0',
#                        'frozenBal': '0',
#                        'imr': '0',
#                        'interest': '',
#                        'isoEq': '0',
#                        'isoLiab': '',
#                        'isoUpl': '0',
#                        'liab': '',
#                        'maxLoan': '',
#                        'mgnRatio': '',
#                        'mmr': '0',
#                        'notionalLever': '0',
#                        'ordFrozen': '0',
#                        'spotInUseAmt': '',
#                        'spotIsoBal': '0',
#                        'stgyEq': '0',
#                        'twap': '0',
#                        'uTime': '1706351191880',
#                        'upl': '0',
#                        'uplLiab': ''},
#                       {'availBal': '0.000999',
#                        'availEq': '0.000999',
#                        'borrowFroz': '',
#                        'cashBal': '0.000999',
#                        'ccy': 'ETH',
#                        'crossLiab': '',
#                        'disEq': '2.28658113',
#                        'eq': '0.000999',
#                        'eqUsd': '2.28658113',
#                        'fixedBal': '0',
#                        'frozenBal': '0',
#                        'imr': '0',
#                        'interest': '',
#                        'isoEq': '0',
#                        'isoLiab': '',
#                        'isoUpl': '0',
#                        'liab': '',
#                        'maxLoan': '',
#                        'mgnRatio': '',
#                        'mmr': '0',
#                        'notionalLever': '0',
#                        'ordFrozen': '0',
#                        'spotInUseAmt': '',
#                        'spotIsoBal': '0',
#                        'stgyEq': '0',
#                        'twap': '0',
#                        'uTime': '1706351152974',
#                        'upl': '0',
#                        'uplLiab': ''}],
#           'imr': '',
#           'isoEq': '9.097727060000002',
#           'mgnRatio': '',
#           'mmr': '',
#           'notionalUsd': '',
#           'ordFroz': '',
#           'totalEq': '101.26649495867409',
#           'uTime': '1706425765301',
#           'upl': ''},
#  'msg': ''}

# %% [markdown]
# ## 5. 获取全部货币余额（字典格式） get_balancesMap

# %%
# instIds 产品列表
# ccys 币种列表
# 参数instIds与ccys默认值为[]，如果均为空，表示全部资产
get_balancesMap = account.get_balancesMap()
eprint(get_balancesMap)
# Out:
# {'code': '0',
#  'data': {'adjEq': '',
#           'borrowFroz': '',
#           'details': {'USDT': {'availBal': '45.767095059637',
#                                'availEq': '45.76709505963701',
#                                'borrowFroz': '',
#                                'cashBal': '49.936428392970335',
#                                'ccy': 'USDT',
#                                '...': '......'},
#                       'MANA': {'availBal': '77.978827031',
#                                'availEq': '77.978827031',
#                                'borrowFroz': '',
#                                'cashBal': '77.978827031',
#                                'ccy': 'MANA',
#                                '...': '......'},
#                       'BTC': {'availBal': '0.0000999',
#                               'availEq': '0.0000999',
#                               'borrowFroz': '',
#                               'cashBal': '0.0000999',
#                               'ccy': 'BTC',
#                               '...': '......'},
#                       'ETH': {'availBal': '0.000999',
#                               'availEq': '0.000999',
#                               'borrowFroz': '',
#                               'cashBal': '0.000999',
#                               'ccy': 'ETH',
#                               '...': '......'},
#                       'IOTA': {'availBal': '0.889068985',
#                                'availEq': '0.889068985',
#                                'borrowFroz': '',
#                                'cashBal': '0.889068985',
#                                'ccy': 'IOTA',
#                                '...': '......'},
#                       '...': '......'},
#           'imr': '',
#           'isoEq': '9.097727060000002',
#           'mgnRatio': '',
#           'mmr': '',
#           'notionalUsd': '',
#           'ordFroz': '',
#           'totalEq': '101.26649495867409',
#           'uTime': '1706425765632',
#           'upl': ''},
#  'msg': ''}

# %%
# 获取BTC和ETH的资产
get_balancesMap = account.get_balancesMap(instIds=['BTC-USDT', 'ETH-USDT'])
eprint(get_balancesMap)
# Out:
# {'code': '0',
#  'data': {'adjEq': '',
#           'borrowFroz': '',
#           'details': {'BTC': {'availBal': '0.0000999',
#                               'availEq': '0.0000999',
#                               'borrowFroz': '',
#                               'cashBal': '0.0000999',
#                               'ccy': 'BTC',
#                               'crossLiab': '',
#                               'disEq': '4.2365292299999995',
#                               'eq': '0.0000999',
#                               'eqUsd': '4.2365292299999995',
#                               'fixedBal': '0',
#                               'frozenBal': '0',
#                               'imr': '0',
#                               'interest': '',
#                               'isoEq': '0',
#                               'isoLiab': '',
#                               'isoUpl': '0',
#                               'liab': '',
#                               'maxLoan': '',
#                               'mgnRatio': '',
#                               'mmr': '0',
#                               'notionalLever': '0',
#                               'ordFrozen': '0',
#                               'spotInUseAmt': '',
#                               'spotIsoBal': '0',
#                               'stgyEq': '0',
#                               'twap': '0',
#                               'uTime': '1706351191880',
#                               'upl': '0',
#                               'uplLiab': ''},
#                       'ETH': {'availBal': '0.000999',
#                               'availEq': '0.000999',
#                               'borrowFroz': '',
#                               'cashBal': '0.000999',
#                               'ccy': 'ETH',
#                               'crossLiab': '',
#                               'disEq': '2.2865711400000004',
#                               'eq': '0.000999',
#                               'eqUsd': '2.2865711400000004',
#                               'fixedBal': '0',
#                               'frozenBal': '0',
#                               'imr': '0',
#                               'interest': '',
#                               'isoEq': '0',
#                               'isoLiab': '',
#                               'isoUpl': '0',
#                               'liab': '',
#                               'maxLoan': '',
#                               'mgnRatio': '',
#                               'mmr': '0',
#                               'notionalLever': '0',
#                               'ordFrozen': '0',
#                               'spotInUseAmt': '',
#                               'spotIsoBal': '0',
#                               'stgyEq': '0',
#                               'twap': '0',
#                               'uTime': '1706351152974',
#                               'upl': '0',
#                               'uplLiab': ''}},
#           'imr': '',
#           'isoEq': '9.097727060000002',
#           'mgnRatio': '',
#           'mmr': '',
#           'notionalUsd': '',
#           'ordFroz': '',
#           'totalEq': '101.26758493567408',
#           'uTime': '1706425766945',
#           'upl': ''},
#  'msg': ''}

# %%
# 获取BTC和ETH的资产
get_balancesMap = account.get_balancesMap(ccys=['BTC', 'ETH'])
eprint(get_balancesMap)
# Out:
# {'code': '0',
#  'data': {'adjEq': '',
#           'borrowFroz': '',
#           'details': {'BTC': {'availBal': '0.0000999',
#                               'availEq': '0.0000999',
#                               'borrowFroz': '',
#                               'cashBal': '0.0000999',
#                               'ccy': 'BTC',
#                               'crossLiab': '',
#                               'disEq': '4.2365292299999995',
#                               'eq': '0.0000999',
#                               'eqUsd': '4.2365292299999995',
#                               'fixedBal': '0',
#                               'frozenBal': '0',
#                               'imr': '0',
#                               'interest': '',
#                               'isoEq': '0',
#                               'isoLiab': '',
#                               'isoUpl': '0',
#                               'liab': '',
#                               'maxLoan': '',
#                               'mgnRatio': '',
#                               'mmr': '0',
#                               'notionalLever': '0',
#                               'ordFrozen': '0',
#                               'spotInUseAmt': '',
#                               'spotIsoBal': '0',
#                               'stgyEq': '0',
#                               'twap': '0',
#                               'uTime': '1706351191880',
#                               'upl': '0',
#                               'uplLiab': ''},
#                       'ETH': {'availBal': '0.000999',
#                               'availEq': '0.000999',
#                               'borrowFroz': '',
#                               'cashBal': '0.000999',
#                               'ccy': 'ETH',
#                               'crossLiab': '',
#                               'disEq': '2.2865711400000004',
#                               'eq': '0.000999',
#                               'eqUsd': '2.2865711400000004',
#                               'fixedBal': '0',
#                               'frozenBal': '0',
#                               'imr': '0',
#                               'interest': '',
#                               'isoEq': '0',
#                               'isoLiab': '',
#                               'isoUpl': '0',
#                               'liab': '',
#                               'maxLoan': '',
#                               'mgnRatio': '',
#                               'mmr': '0',
#                               'notionalLever': '0',
#                               'ordFrozen': '0',
#                               'spotInUseAmt': '',
#                               'spotIsoBal': '0',
#                               'stgyEq': '0',
#                               'twap': '0',
#                               'uTime': '1706351152974',
#                               'upl': '0',
#                               'uplLiab': ''}},
#           'imr': '',
#           'isoEq': '9.097727060000002',
#           'mgnRatio': '',
#           'mmr': '',
#           'notionalUsd': '',
#           'ordFroz': '',
#           'totalEq': '101.26728494467409',
#           'uTime': '1706425767248',
#           'upl': ''},
#  'msg': ''}

# %% [markdown]
# ## 6. 设置持仓模式 set_marginType

# %%
set_position_mode = account.set_position_mode(
    posMode='long_short_mode',
)

eprint(set_position_mode)
# Out:
# {'code': '59000',
#  'data': [],
#  'msg': 'Setting failed. Cancel any open orders, close positions, and stop trading bots first.'}

# %% [markdown]
# ## 7. 调整开仓杠杆 set_leverage

# %% [markdown]
# ### 7.1 设置逐仓杠杆（多仓）

# %%
set_leverage_isolated_long = account.set_leverage(
    lever=1,
    instId='BTC-USDT-SWAP',
    mgnMode='isolated',
    posSide='long',
)

eprint(set_leverage_isolated_long)
# Out:
# {'code': '0', 'data': [{'instId': 'BTC-USDT-SWAP', 'lever': '1', 'mgnMode': 'isolated', 'posSide': 'long'}], 'msg': ''}

# %% [markdown]
# ### 7.2 设置逐仓杠杆（空仓）

# %%
set_leverage_isolated_short = account.set_leverage(
    lever=1,
    instId='MANA-USDT-SWAP',
    mgnMode='isolated',
    posSide='short',
)

eprint(set_leverage_isolated_short)
# Out:
# {'code': '0',
#  'data': [{'instId': 'MANA-USDT-SWAP', 'lever': '1', 'mgnMode': 'isolated', 'posSide': 'short'}],
#  'msg': ''}

# %% [markdown]
# ### 7.3 设置全仓杠杆

# %%
set_leverage_cross = account.set_leverage(
    lever=4,
    instId='MANA-USDT-SWAP',
    mgnMode='cross',
    posSide='',
)

eprint(set_leverage_cross)
# Out:
# {'code': '0', 'data': [{'instId': 'MANA-USDT-SWAP', 'lever': '4', 'mgnMode': 'cross', 'posSide': ''}], 'msg': ''}

# %% [markdown]
# ## 8. 获取杠杆倍数 get_leverage

# %% [markdown]
# ### 8.1 获取逐仓杠杆

# %%
get_leverage_isolated = account.get_leverage(
    instId='BTC-USDT-SWAP',
    mgnMode='isolated',
)

eprint(get_leverage_isolated)
# Out:
# {'code': '0',
#  'data': {'long': {'instId': 'BTC-USDT-SWAP', 'lever': '1', 'mgnMode': 'isolated', 'posSide': 'long'},
#           'short': {'instId': 'BTC-USDT-SWAP', 'lever': '2', 'mgnMode': 'isolated', 'posSide': 'short'}},
#  'msg': ''}

# %% [markdown]
# ### 8.2 获取全仓杠杆

# %%
get_leverage_cross = okxSWAP.account.get_leverage(
    instId='BTC-USDT-SWAP',
    mgnMode='cross',
)

eprint(get_leverage_cross)
# Out:
# {'code': '0',
#  'data': {'long': {'instId': 'BTC-USDT-SWAP', 'lever': '2', 'mgnMode': 'cross', 'posSide': 'long'},
#           'short': {'instId': 'BTC-USDT-SWAP', 'lever': '2', 'mgnMode': 'cross', 'posSide': 'short'}},
#  'msg': ''}

# %% [markdown]
# ## 9. 获取单个产品的持仓信息 get_position

# %%
get_position_result = account.get_position(instId='MANA-USDT-SWAP')
eprint(get_position_result)
# Out:
# {'code': '0',
#  'data': [{'adl': '1', 'availPos': '1', 'avgPx': '0.4548', 'baseBal': '', 'baseBorrowed': '', '...': '......'},
#           {'adl': '1', 'availPos': '1', 'avgPx': '0.4549', 'baseBal': '', 'baseBorrowed': '', '...': '......'},
#           {'adl': '2', 'availPos': '1', 'avgPx': '0.4549', 'baseBal': '', 'baseBorrowed': '', '...': '......'},
#           {'adl': '1', 'availPos': '1', 'avgPx': '0.4548', 'baseBal': '', 'baseBorrowed': '', '...': '......'}],
#  'msg': ''}

# %%
get_position_result = account.get_position(instId='MANA-USDT-SWAP', mgnMode='isolated')
eprint(get_position_result, length=40)
# Out:
# {'code': '0',
#  'data': [{'adl': '2',
#            'availPos': '1',
#            'avgPx': '0.4549',
#            'baseBal': '',
#            'baseBorrowed': '',
#            'baseInterest': '',
#            'bePx': '0.4544453273363319',
#            'bizRefId': '',
#            'bizRefType': '',
#            'cTime': '1706425058368',
#            'ccy': 'USDT',
#            'closeOrderAlgo': [],
#            'deltaBS': '',
#            'deltaPA': '',
#            'fee': '-0.0022745',
#            'fundingFee': '0',
#            'gammaBS': '',
#            'gammaPA': '',
#            'idxPx': '0.4550',
#            'imr': '',
#            'instId': 'MANA-USDT-SWAP',
#            'instType': 'SWAP',
#            'interest': '',
#            'last': '0.455',
#            'lever': '1',
#            'liab': '',
#            'liabCcy': '',
#            'liqPenalty': '0',
#            'liqPx': '0.9033756703078453',
#            'margin': '4.549',
#            'markPx': '0.4551',
#            'mgnMode': 'isolated',
#            'mgnRatio': '142.73158175597203',
#            'mmr': '0.0295815',
#            'notionalUsd': '4.55086347',
#            'optVal': '',
#            'pendingCloseOrdLiabVal': '',
#            'pnl': '0',
#            'pos': '1',
#            'posCcy': '',
#            '...': '......'},
#           {'adl': '1',
#            'availPos': '1',
#            'avgPx': '0.4548',
#            'baseBal': '',
#            'baseBorrowed': '',
#            'baseInterest': '',
#            'bePx': '0.4552550275137568',
#            'bizRefId': '',
#            'bizRefType': '',
#            'cTime': '1706425035111',
#            'ccy': 'USDT',
#            'closeOrderAlgo': [],
#            'deltaBS': '',
#            'deltaPA': '',
#            'fee': '-0.002274',
#            'fundingFee': '0',
#            'gammaBS': '',
#            'gammaPA': '',
#            'idxPx': '0.4550',
#            'imr': '',
#            'instId': 'MANA-USDT-SWAP',
#            'instType': 'SWAP',
#            'interest': '',
#            'last': '0.455',
#            'lever': '1',
#            'liab': '',
#            'liabCcy': '',
#            'liqPenalty': '0',
#            'liqPx': '0',
#            'margin': '4.548',
#            'markPx': '0.4551',
#            'mgnMode': 'isolated',
#            'mgnRatio': '142.8571428571429',
#            'mmr': '0.0295815',
#            'notionalUsd': '4.55086347',
#            'optVal': '',
#            'pendingCloseOrdLiabVal': '',
#            'pnl': '0',
#            'pos': '1',
#            'posCcy': '',
#            '...': '......'}],
#  'msg': ''}

# %%
get_position_result = account.get_position(instId='MANA-USDT-SWAP', mgnMode='cross', posSide='long')
eprint(get_position_result, length=40)
# Out:
# {'code': '0',
#  'data': [{'adl': '1',
#            'availPos': '1',
#            'avgPx': '0.4549',
#            'baseBal': '',
#            'baseBorrowed': '',
#            'baseInterest': '',
#            'bePx': '0.4553551275637819',
#            'bizRefId': '',
#            'bizRefType': '',
#            'cTime': '1706425239610',
#            'ccy': 'USDT',
#            'closeOrderAlgo': [],
#            'deltaBS': '',
#            'deltaPA': '',
#            'fee': '-0.0022745',
#            'fundingFee': '0',
#            'gammaBS': '',
#            'gammaPA': '',
#            'idxPx': '0.4550',
#            'imr': '1.13775',
#            'instId': 'MANA-USDT-SWAP',
#            'instType': 'SWAP',
#            'interest': '',
#            'last': '0.455',
#            'lever': '4',
#            'liab': '',
#            'liabCcy': '',
#            'liqPenalty': '0',
#            'liqPx': '356.45230066407385',
#            'margin': '',
#            'markPx': '0.4551',
#            'mgnMode': 'cross',
#            'mgnRatio': '481.98305151568115',
#            'mmr': '0.0295815',
#            'notionalUsd': '4.55086347',
#            'optVal': '',
#            'pendingCloseOrdLiabVal': '',
#            'pnl': '0',
#            'pos': '1',
#            'posCcy': '',
#            '...': '......'}],
#  'msg': ''}

# %% [markdown]
# ## 9. 获取全部产品的持仓信息（列表格式） get_positions

# %%
# 参数：产品列表 instIds 默认为[] 表示全部产品
get_positions_result = account.get_positions()
eprint(get_positions_result)
# Out:
# {'code': '0',
#  'data': [{'adl': '1', 'availPos': '1', 'avgPx': '56.931', 'baseBal': '', 'baseBorrowed': '', '...': '......'},
#           {'adl': '1', 'availPos': '1', 'avgPx': '0.4548', 'baseBal': '', 'baseBorrowed': '', '...': '......'},
#           {'adl': '1', 'availPos': '1', 'avgPx': '0.4549', 'baseBal': '', 'baseBorrowed': '', '...': '......'},
#           {'adl': '2', 'availPos': '1', 'avgPx': '0.4549', 'baseBal': '', 'baseBorrowed': '', '...': '......'},
#           {'adl': '1', 'availPos': '1', 'avgPx': '0.4548', 'baseBal': '', 'baseBorrowed': '', '...': '......'}],
#  'msg': ''}

# %%
get_positions_result = account.get_positions(instIds=['MANA-USDT-SWAP', ])
eprint(get_positions_result)
# Out:
# {'code': '0',
#  'data': [{'adl': '1', 'availPos': '1', 'avgPx': '0.4548', 'baseBal': '', 'baseBorrowed': '', '...': '......'},
#           {'adl': '1', 'availPos': '1', 'avgPx': '0.4549', 'baseBal': '', 'baseBorrowed': '', '...': '......'},
#           {'adl': '2', 'availPos': '1', 'avgPx': '0.4549', 'baseBal': '', 'baseBorrowed': '', '...': '......'},
#           {'adl': '1', 'availPos': '1', 'avgPx': '0.4548', 'baseBal': '', 'baseBorrowed': '', '...': '......'}],
#  'msg': ''}

# %% [markdown]
# ## 10. 获取全部产品的持仓信息字典（字典格式） get_positionsMap

# %%
get_positionsMap_result = account.get_positionsMap()
eprint(get_positionsMap_result)
# Out:
# {'code': '0',
#  'data': {'isolated': {'long': {'MANA-USDT-SWAP': {'adl': '1',
#                                                    'availPos': '1',
#                                                    'avgPx': '0.4548',
#                                                    'baseBal': '',
#                                                    'baseBorrowed': '',
#                                                    'baseInterest': '',
#                                                    'bePx': '0.4552550275137568',
#                                                    'bizRefId': '',
#                                                    'bizRefType': '',
#                                                    'cTime': '1706425035111',
#                                                    'ccy': 'USDT',
#                                                    'closeOrderAlgo': [],
#                                                    'deltaBS': '',
#                                                    'deltaPA': '',
#                                                    'fee': '-0.002274',
#                                                    'fundingFee': '0',
#                                                    'gammaBS': '',
#                                                    'gammaPA': '',
#                                                    'idxPx': '0.4550',
#                                                    'imr': '',
#                                                    'instId': 'MANA-USDT-SWAP',
#                                                    'instType': 'SWAP',
#                                                    'interest': '',
#                                                    'last': '0.455',
#                                                    'lever': '1',
#                                                    'liab': '',
#                                                    'liabCcy': '',
#                                                    'liqPenalty': '0',
#                                                    'liqPx': '0',
#                                                    'margin': '4.548',
#                                                    'markPx': '0.4551',
#                                                    'mgnMode': 'isolated',
#                                                    'mgnRatio': '142.8571428571429',
#                                                    'mmr': '0.0295815',
#                                                    'notionalUsd': '4.55086347',
#                                                    'optVal': '',
#                                                    'pendingCloseOrdLiabVal': '',
#                                                    'pnl': '0',
#                                                    'pos': '1',
#                                                    'posCcy': '',
#                                                    'posId': '671385779520049153',
#                                                    'posSide': 'long',
#                                                    'quoteBal': '',
#                                                    'quoteBorrowed': '',
#                                                    'quoteInterest': '',
#                                                    'realizedPnl': '-0.002274',
#                                                    'spotInUseAmt': '',
#                                                    'spotInUseCcy': '',
#                                                    'thetaBS': '',
#                                                    'thetaPA': '',
#                                                    'tradeId': '83463968',
#                                                    'uTime': '1706425035111',
#                                                    'upl': '0.0030000000000002',
#                                                    'uplLastPx': '0.0020000000000003',
#                                                    'uplRatio': '0.0006596306068603',
#                                                    'uplRatioLastPx': '0.0004397537379068',
#                                                    'usdPx': '',
#                                                    'vegaBS': '',
#                                                    'vegaPA': ''}},
#                        'short': {'MANA-USDT-SWAP': {'adl': '2',
#                                                     'availPos': '1',
#                                                     'avgPx': '0.4549',
#                                                     'baseBal': '',
#                                                     'baseBorrowed': '',
#                                                     'baseInterest': '',
#                                                     'bePx': '0.4544453273363319',
#                                                     'bizRefId': '',
#                                                     'bizRefType': '',
#                                                     'cTime': '1706425058368',
#                                                     'ccy': 'USDT',
#                                                     'closeOrderAlgo': [],
#                                                     'deltaBS': '',
#                                                     'deltaPA': '',
#                                                     'fee': '-0.0022745',
#                                                     'fundingFee': '0',
#                                                     'gammaBS': '',
#                                                     'gammaPA': '',
#                                                     'idxPx': '0.4550',
#                                                     'imr': '',
#                                                     'instId': 'MANA-USDT-SWAP',
#                                                     'instType': 'SWAP',
#                                                     'interest': '',
#                                                     'last': '0.455',
#                                                     'lever': '1',
#                                                     'liab': '',
#                                                     'liabCcy': '',
#                                                     'liqPenalty': '0',
#                                                     'liqPx': '0.9033756703078453',
#                                                     'margin': '4.549',
#                                                     'markPx': '0.4551',
#                                                     'mgnMode': 'isolated',
#                                                     'mgnRatio': '142.73158175597203',
#                                                     'mmr': '0.0295815',
#                                                     'notionalUsd': '4.55086347',
#                                                     'optVal': '',
#                                                     'pendingCloseOrdLiabVal': '',
#                                                     'pnl': '0',
#                                                     'pos': '1',
#                                                     'posCcy': '',
#                                                     'posId': '671385841784492040',
#                                                     'posSide': 'short',
#                                                     'quoteBal': '',
#                                                     'quoteBorrowed': '',
#                                                     'quoteInterest': '',
#                                                     'realizedPnl': '-0.0022745',
#                                                     'spotInUseAmt': '',
#                                                     'spotInUseCcy': '',
#                                                     'thetaBS': '',
#                                                     'thetaPA': '',
#                                                     'tradeId': '83463972',
#                                                     'uTime': '1706425058368',
#                                                     'upl': '-0.0019999999999998',
#                                                     'uplLastPx': '-0.0009999999999999',
#                                                     'uplRatio': '-0.0004396570674874',
#                                                     'uplRatioLastPx': '-0.0002198285337436',
#                                                     'usdPx': '',
#                                                     'vegaBS': '',
#                                                     'vegaPA': ''}}},
#           'cross': {'long': {'ORDI-USDT-SWAP': {'adl': '1',
#                                                 'availPos': '1',
#                                                 'avgPx': '56.931',
#                                                 'baseBal': '',
#                                                 'baseBorrowed': '',
#                                                 'baseInterest': '',
#                                                 'bePx': '56.987959479739864',
#                                                 'bizRefId': '',
#                                                 'bizRefType': '',
#                                                 'cTime': '1706425628407',
#                                                 'ccy': 'USDT',
#                                                 'closeOrderAlgo': [],
#                                                 'deltaBS': '',
#                                                 'deltaPA': '',
#                                                 'fee': '-0.00284655',
#                                                 'fundingFee': '0',
#                                                 'gammaBS': '',
#                                                 'gammaPA': '',
#                                                 'idxPx': '57.026',
#                                                 'imr': '1.900266666666667',
#                                                 'instId': 'ORDI-USDT-SWAP',
#                                                 'instType': 'SWAP',
#                                                 'interest': '',
#                                                 'last': '57.006',
#                                                 'lever': '3',
#                                                 'liab': '',
#                                                 'liabCcy': '',
#                                                 'liqPenalty': '0',
#                                                 'liqPx': '',
#                                                 'margin': '',
#                                                 'markPx': '57.008',
#                                                 'mgnMode': 'cross',
#                                                 'mgnRatio': '481.9853424735314',
#                                                 'mmr': '0.0370552',
#                                                 'notionalUsd': '5.700628976000001',
#                                                 'optVal': '',
#                                                 'pendingCloseOrdLiabVal': '',
#                                                 'pnl': '0',
#                                                 'pos': '1',
#                                                 'posCcy': '',
#                                                 'posId': '671733004242685953',
#                                                 'posSide': 'long',
#                                                 'quoteBal': '',
#                                                 'quoteBorrowed': '',
#                                                 'quoteInterest': '',
#                                                 'realizedPnl': '-0.00284655',
#                                                 'spotInUseAmt': '',
#                                                 'spotInUseCcy': '',
#                                                 'thetaBS': '',
#                                                 'thetaPA': '',
#                                                 'tradeId': '250829390',
#                                                 'uTime': '1706425628407',
#                                                 'upl': '0.0077000000000005',
#                                                 'uplLastPx': '0.0075000000000003',
#                                                 'uplRatio': '0.0040575433419403',
#                                                 'uplRatioLastPx': '0.0039521526057862',
#                                                 'usdPx': '',
#                                                 'vegaBS': '',
#                                                 'vegaPA': ''},
#                              'MANA-USDT-SWAP': {'adl': '1',
#                                                 'availPos': '1',
#                                                 'avgPx': '0.4549',
#                                                 'baseBal': '',
#                                                 'baseBorrowed': '',
#                                                 'baseInterest': '',
#                                                 'bePx': '0.4553551275637819',
#                                                 'bizRefId': '',
#                                                 'bizRefType': '',
#                                                 'cTime': '1706425239610',
#                                                 'ccy': 'USDT',
#                                                 'closeOrderAlgo': [],
#                                                 'deltaBS': '',
#                                                 'deltaPA': '',
#                                                 'fee': '-0.0022745',
#                                                 'fundingFee': '0',
#                                                 'gammaBS': '',
#                                                 'gammaPA': '',
#                                                 'idxPx': '0.4550',
#                                                 'imr': '1.13775',
#                                                 'instId': 'MANA-USDT-SWAP',
#                                                 'instType': 'SWAP',
#                                                 'interest': '',
#                                                 'last': '0.455',
#                                                 'lever': '4',
#                                                 'liab': '',
#                                                 'liabCcy': '',
#                                                 'liqPenalty': '0',
#                                                 'liqPx': '356.4515913783595',
#                                                 'margin': '',
#                                                 'markPx': '0.4551',
#                                                 'mgnMode': 'cross',
#                                                 'mgnRatio': '481.9853424735314',
#                                                 'mmr': '0.0295815',
#                                                 'notionalUsd': '4.55086347',
#                                                 'optVal': '',
#                                                 'pendingCloseOrdLiabVal': '',
#                                                 'pnl': '0',
#                                                 'pos': '1',
#                                                 'posCcy': '',
#                                                 'posId': '671731373509873668',
#                                                 'posSide': 'long',
#                                                 'quoteBal': '',
#                                                 'quoteBorrowed': '',
#                                                 'quoteInterest': '',
#                                                 'realizedPnl': '-0.0022745',
#                                                 'spotInUseAmt': '',
#                                                 'spotInUseCcy': '',
#                                                 'thetaBS': '',
#                                                 'thetaPA': '',
#                                                 'tradeId': '83464039',
#                                                 'uTime': '1706425769070',
#                                                 'upl': '0.0019999999999998',
#                                                 'uplLastPx': '0.0009999999999999',
#                                                 'uplRatio': '0.0017586282699495',
#                                                 'uplRatioLastPx': '0.0008793141349743',
#                                                 'usdPx': '',
#                                                 'vegaBS': '',
#                                                 'vegaPA': ''}},
#                     'short': {'MANA-USDT-SWAP': {'adl': '1',
#                                                  'availPos': '1',
#                                                  'avgPx': '0.4548',
#                                                  'baseBal': '',
#                                                  'baseBorrowed': '',
#                                                  'baseInterest': '',
#                                                  'bePx': '0.4543454272863569',
#                                                  'bizRefId': '',
#                                                  'bizRefType': '',
#                                                  'cTime': '1706425244359',
#                                                  'ccy': 'USDT',
#                                                  'closeOrderAlgo': [],
#                                                  'deltaBS': '',
#                                                  'deltaPA': '',
#                                                  'fee': '-0.002274',
#                                                  'fundingFee': '0',
#                                                  'gammaBS': '',
#                                                  'gammaPA': '',
#                                                  'idxPx': '0.4550',
#                                                  'imr': '1.13775',
#                                                  'instId': 'MANA-USDT-SWAP',
#                                                  'instType': 'SWAP',
#                                                  'interest': '',
#                                                  'last': '0.455',
#                                                  'lever': '4',
#                                                  'liab': '',
#                                                  'liabCcy': '',
#                                                  'liqPenalty': '0',
#                                                  'liqPx': '356.4515913783595',
#                                                  'margin': '',
#                                                  'markPx': '0.4551',
#                                                  'mgnMode': 'cross',
#                                                  'mgnRatio': '481.9853424735314',
#                                                  'mmr': '0.0295815',
#                                                  'notionalUsd': '4.55086347',
#                                                  'optVal': '',
#                                                  'pendingCloseOrdLiabVal': '',
#                                                  'pnl': '0',
#                                                  'pos': '1',
#                                                  'posCcy': '',
#                                                  'posId': '671731393428623360',
#                                                  'posSide': 'short',
#                                                  'quoteBal': '',
#                                                  'quoteBorrowed': '',
#                                                  'quoteInterest': '',
#                                                  'realizedPnl': '-0.002274',
#                                                  'spotInUseAmt': '',
#                                                  'spotInUseCcy': '',
#                                                  'thetaBS': '',
#                                                  'thetaPA': '',
#                                                  'tradeId': '83464045',
#                                                  'uTime': '1706425769070',
#                                                  'upl': '-0.0030000000000002',
#                                                  'uplLastPx': '-0.0020000000000003',
#                                                  'uplRatio': '-0.002638522427441',
#                                                  'uplRatioLastPx': '-0.0017590149516273',
#                                                  'usdPx': '',
#                                                  'vegaBS': '',
#                                                  'vegaPA': ''}}}},
#  'msg': ''}

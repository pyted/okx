# %% [markdown]
# ## 1. APP 现货交易-市价单开仓函数总览

# %% [markdown]
# |方法|解释|
# |:---|:---|
# |open_market|市价单购买|

# %% [markdown]
# ## 2. 模型实例化

# %%
from okx.app import OkxSPOT
from pprint import pprint

# %%
# 现货交易账户需要秘钥
key = "xxx"
secret = "xxx"
passphrase = "xxx"
# 实盘：0，虚拟盘：1
flag = '0'
# 使用http和https代理，proxies={'http':'xxxxx','https:':'xxxxx'}，与requests中的proxies参数规则相同
proxies = {}
# 转发：需搭建转发服务器，可参考：https://github.com/pyted/okx_resender
proxy_host = None

okxSPOT = OkxSPOT(
    key=key, secret=secret, passphrase=passphrase, proxies=proxies, proxy_host=proxy_host,
)
trade = okxSPOT.trade

# %% [markdown]
# ## 3. 同步 市价开仓（购买）

# %%
open_market3 = trade.open_market(
    instId='MANA-USDT',  # 产品
    openMoney=5,  # 开仓金额 开仓金额openMoney和开仓数量quantity必须输入其中一个 优先级：quantity > openMoney
    # quantity=10,  # 开仓数量
    tag='',  # 订单标签
    clOrdId='',  # 客户自定义订单ID
    meta={},  # 向回调函数中传递的参数字典
)

pprint(open_market3)
# Out:
# {'cancel_result': None,
#  'error_result': None,
#  'func_param': {'callback': None,
#                 'cancel': True,
#                 'clOrdId': '',
#                 'delay': 0.2,
#                 'errorback': None,
#                 'instId': 'MANA-USDT',
#                 'meta': {},
#                 'newThread': False,
#                 'openMoney': 5,
#                 'quantity': None,
#                 'tag': '',
#                 'timeout': 60},
#  'get_order_result': {'code': '0',
#                       'data': {'accFillSz': '11.11358',
#                                'algoClOrdId': '',
#                                'algoId': '',
#                                'attachAlgoClOrdId': '',
#                                'attachAlgoOrds': [],
#                                'avgPx': '0.45',
#                                'cTime': '1706365559994',
#                                'cancelSource': '',
#                                'cancelSourceReason': '',
#                                'category': 'normal',
#                                'ccy': '',
#                                'clOrdId': '',
#                                'fee': '-0.01111358',
#                                'feeCcy': 'MANA',
#                                'fillPx': '0.45',
#                                'fillSz': '11.11358',
#                                'fillTime': '1706365559995',
#                                'instId': 'MANA-USDT',
#                                'instType': 'SPOT',
#                                'lever': '',
#                                'ordId': '671481059057766404',
#                                'ordType': 'market',
#                                'pnl': '0',
#                                'posSide': 'net',
#                                'px': '',
#                                'pxType': '',
#                                'pxUsd': '',
#                                'pxVol': '',
#                                'quickMgnType': '',
#                                'rebate': '0',
#                                'rebateCcy': 'USDT',
#                                'reduceOnly': 'false',
#                                'side': 'buy',
#                                'slOrdPx': '',
#                                'slTriggerPx': '',
#                                'slTriggerPxType': '',
#                                'source': '',
#                                'state': 'filled',
#                                'stpId': '',
#                                'stpMode': '',
#                                'sz': '11.11358',
#                                'tag': '',
#                                'tdMode': 'cash',
#                                'tgtCcy': 'base_ccy',
#                                'tpOrdPx': '',
#                                'tpTriggerPx': '',
#                                'tpTriggerPxType': '',
#                                'tradeId': '36684885',
#                                'uTime': '1706365559998'},
#                       'msg': ''},
#  'instId': 'MANA-USDT',
#  'instType': 'SPOT',
#  'meta': {},
#  'ordId': '671481059057766404',
#  'request_param': {'clOrdId': '',
#                    'instId': 'MANA-USDT',
#                    'ordType': 'market',
#                    'side': 'buy',
#                    'sz': '11.113580',
#                    'tag': '',
#                    'tdMode': 'cash',
#                    'tgtCcy': 'base_ccy'},
#  'set_order_result': {'code': '0',
#                       'data': {'clOrdId': '',
#                                'ordId': '671481059057766404',
#                                'sCode': '0',
#                                'sMsg': 'Order placed',
#                                'tag': ''},
#                       'inTime': '1706365559993538',
#                       'msg': '',
#                       'outTime': '1706365559995741'},
#  'state': 'filled'}

# %% [markdown]
# ## 4. 同步 市价开仓（购买） 回调函数

# %%
# 执行成功回调
def callback4(information):
    print('callback')
    pprint(information)


# 执行错误回调
def errorback4(information):
    print('errorback')
    pprint(information)

# %%
open_market4 = trade.open_market(
    instId='MANA-USDT',  # 产品
    openMoney=6,  # 开仓金额 开仓金额openMoney和开仓数量quantity必须输入其中一个 优先级：quantity > openMoney
    # quantity=3,  # 开仓数量
    tag='',  # 订单标签
    clOrdId='',  # 客户自定义订单ID
    meta={},  # 向回调函数中传递的参数字典

    callback=callback4,  # 开仓成功触发的回调函数
    errorback=errorback4,  # 开仓失败触发的回调函数
)
# Out:
# callback
# {'cancel_result': None,
#  'error_result': None,
#  'func_param': {'callback': <function callback4 at 0x7fb238894dc0>,
#                 'cancel': True,
#                 'clOrdId': '',
#                 'delay': 0.2,
#                 'errorback': <function errorback4 at 0x7fb238894ca0>,
#                 'instId': 'MANA-USDT',
#                 'meta': {},
#                 'newThread': False,
#                 'openMoney': 6,
#                 'quantity': None,
#                 'tag': '',
#                 'timeout': 60},
#  'get_order_result': {'code': '0',
#                       'data': {'accFillSz': '13.333333',
#                                'algoClOrdId': '',
#                                'algoId': '',
#                                'attachAlgoClOrdId': '',
#                                'attachAlgoOrds': [],
#                                'avgPx': '0.45',
#                                'cTime': '1706365571138',
#                                'cancelSource': '',
#                                'cancelSourceReason': '',
#                                'category': 'normal',
#                                'ccy': '',
#                                'clOrdId': '',
#                                'fee': '-0.013333333',
#                                'feeCcy': 'MANA',
#                                'fillPx': '0.45',
#                                'fillSz': '13.333333',
#                                'fillTime': '1706365571139',
#                                'instId': 'MANA-USDT',
#                                'instType': 'SPOT',
#                                'lever': '',
#                                'ordId': '671481105799090184',
#                                'ordType': 'market',
#                                'pnl': '0',
#                                'posSide': 'net',
#                                'px': '',
#                                'pxType': '',
#                                'pxUsd': '',
#                                'pxVol': '',
#                                'quickMgnType': '',
#                                'rebate': '0',
#                                'rebateCcy': 'USDT',
#                                'reduceOnly': 'false',
#                                'side': 'buy',
#                                'slOrdPx': '',
#                                'slTriggerPx': '',
#                                'slTriggerPxType': '',
#                                'source': '',
#                                'state': 'filled',
#                                'stpId': '',
#                                'stpMode': '',
#                                'sz': '13.333333',
#                                'tag': '',
#                                'tdMode': 'cash',
#                                'tgtCcy': 'base_ccy',
#                                'tpOrdPx': '',
#                                'tpTriggerPx': '',
#                                'tpTriggerPxType': '',
#                                'tradeId': '36684886',
#                                'uTime': '1706365571142'},
#                       'msg': ''},
#  'instId': 'MANA-USDT',
#  'instType': 'SPOT',
#  'meta': {},
#  'ordId': '671481105799090184',
#  'request_param': {'clOrdId': '',
#                    'instId': 'MANA-USDT',
#                    'ordType': 'market',
#                    'side': 'buy',
#                    'sz': '13.333333',
#                    'tag': '',
#                    'tdMode': 'cash',
#                    'tgtCcy': 'base_ccy'},
#  'set_order_result': {'code': '0',
#                       'data': {'clOrdId': '',
#                                'ordId': '671481105799090184',
#                                'sCode': '0',
#                                'sMsg': 'Order placed',
#                                'tag': ''},
#                       'inTime': '1706365571137335',
#                       'msg': '',
#                       'outTime': '1706365571139374'},
#  'state': 'filled'}

# %% [markdown]
# ## 5. 异步 市价开仓（购买）回调函数

# %%
# 执行成功回调
def callback5(information):
    print('thread callback')
    pprint(information)


# 执行错误回调
def errorback5(information):
    print('thread errorback')
    pprint(information)

# %%
# 设置newThread=True
open_market5 = okxSPOT.trade.open_market(
    instId='MANA-USDT',  # 产品
    openMoney=5,  # 开仓金额 开仓金额openMoney和开仓数量quantity必须输入其中一个 优先级：quantity > openMoney
    # quantity=3,  # 开仓数量
    callback=callback5,  # 开仓成功触发的回调函数
    errorback=errorback5,  # 开仓失败触发的回调函数
    tag='',  # 订单标签
    clOrdId='',  # 客户自定义订单ID
    meta={},  # 向回调函数中传递的参数字典

    newThread=True,  # 是否开启一个新的线程维护这个订单
)
pprint(open_market5)
print('-' * 30)
# Out:
# <Thread(Thread-5, started 123145593274368)>
# ------------------------------
# thread callback
# {'cancel_result': None,
#  'error_result': None,
#  'func_param': {'callback': <function callback5 at 0x7fd510bfbca0>,
#                 'cancel': True,
#                 'clOrdId': '',
#                 'delay': 0.2,
#                 'errorback': <function errorback5 at 0x7fd510bfb8b0>,
#                 'instId': 'MANA-USDT',
#                 'meta': {},
#                 'newThread': True,
#                 'openMoney': 5,
#                 'quantity': None,
#                 'tag': '',
#                 'timeout': 60},
#  'get_order_result': {'code': '0',
#                       'data': {'accFillSz': '11.116051',
#                                'algoClOrdId': '',
#                                'algoId': '',
#                                'attachAlgoClOrdId': '',
#                                'attachAlgoOrds': [],
#                                'avgPx': '0.4498',
#                                'cTime': '1706365678170',
#                                'cancelSource': '',
#                                'cancelSourceReason': '',
#                                'category': 'normal',
#                                'ccy': '',
#                                'clOrdId': '',
#                                'fee': '-0.011116051',
#                                'feeCcy': 'MANA',
#                                'fillPx': '0.4498',
#                                'fillSz': '11.116051',
#                                'fillTime': '1706365678171',
#                                'instId': 'MANA-USDT',
#                                'instType': 'SPOT',
#                                'lever': '',
#                                'ordId': '671481554723835904',
#                                'ordType': 'market',
#                                'pnl': '0',
#                                'posSide': 'net',
#                                'px': '',
#                                'pxType': '',
#                                'pxUsd': '',
#                                'pxVol': '',
#                                'quickMgnType': '',
#                                'rebate': '0',
#                                'rebateCcy': 'USDT',
#                                'reduceOnly': 'false',
#                                'side': 'buy',
#                                'slOrdPx': '',
#                                'slTriggerPx': '',
#                                'slTriggerPxType': '',
#                                'source': '',
#                                'state': 'filled',
#                                'stpId': '',
#                                'stpMode': '',
#                                'sz': '11.116051',
#                                'tag': '',
#                                'tdMode': 'cash',
#                                'tgtCcy': 'base_ccy',
#                                'tpOrdPx': '',
#                                'tpTriggerPx': '',
#                                'tpTriggerPxType': '',
#                                'tradeId': '36684887',
#                                'uTime': '1706365678174'},
#                       'msg': ''},
#  'instId': 'MANA-USDT',
#  'instType': 'SPOT',
#  'meta': {},
#  'ordId': '671481554723835904',
#  'request_param': {'clOrdId': '',
#                    'instId': 'MANA-USDT',
#                    'ordType': 'market',
#                    'side': 'buy',
#                    'sz': '11.116051',
#                    'tag': '',
#                    'tdMode': 'cash',
#                    'tgtCcy': 'base_ccy'},
#  'set_order_result': {'code': '0',
#                       'data': {'clOrdId': '',
#                                'ordId': '671481554723835904',
#                                'sCode': '0',
#                                'sMsg': 'Order placed',
#                                'tag': ''},
#                       'inTime': '1706365678170757',
#                       'msg': '',
#                       'outTime': '1706365678172037'},
#  'state': 'filled'}

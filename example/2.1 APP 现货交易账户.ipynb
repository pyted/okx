# %%
from okx.app import OkxSPOT
from okx.app import AccountSPOT

# %% [markdown]
# ## 1. 实例化OkxSPOT

# %%
# okxSPOT.account 等同于 accountSPOT
okxSPOT = OkxSPOT(
    key="xxx",
    secret="xxx",
    passphrase="xxx",
    # 使用http和https代理，proxies={'http':'xxxxx','https:':'xxxxx'}，通requests中的proxies参数规则相同
    proxies={},
    # 转发：需搭建转发服务器，可参考：https://github.com/pyted/okx_resender
    proxy_host=None, 
)
# accountSPOT = AccountSPOT(
#     key="xxx",
#     secret="xxx",
#     passphrase="xxx",
#     # 使用http和https代理，proxies={'http':'xxxxx','https:':'xxxxx'}，通requests中的proxies参数规则相同
#     proxies={},
#     # 转发：需搭建转发服务器，可参考：https://github.com/pyted/okx_resender
#     proxy_host=None, 
# )

# %% [markdown]
# ## 2. 获取产品的余额

# %%
# 支持传入instId 等同于okxSPOT.account.get_balance(ccy='MANA')
get_balance = okxSPOT.account.get_balance(instId='MANA-USDT')

get_balance
# Out:
# {'code': '0',
#  'data': {'adjEq': '',
#   'borrowFroz': '',
#   'details': {'availBal': '5.645662641',
#    'availEq': '5.645662641',
#    'borrowFroz': '',
#    'cashBal': '5.645662641',
#    'ccy': 'MANA',
#    'crossLiab': '',
#    'disEq': '1.79769189814722',
#    'eq': '5.645662641',
#    'eqUsd': '1.9974354423858',
#    'fixedBal': '0',
#    'frozenBal': '0',
#    'interest': '',
#    'isoEq': '0',
#    'isoLiab': '',
#    'isoUpl': '0',
#    'liab': '',
#    'maxLoan': '',
#    'mgnRatio': '',
#    'notionalLever': '0',
#    'ordFrozen': '0',
#    'spotInUseAmt': '',
#    'spotIsoBal': '0',
#    'stgyEq': '0',
#    'twap': '0',
#    'uTime': '1698292242158',
#    'upl': '0',
#    'uplLiab': ''},
#   'imr': '',
#   'isoEq': '0',
#   'mgnRatio': '',
#   'mmr': '',
#   'notionalUsd': '',
#   'ordFroz': '',
#   'totalEq': '100.02285438205632',
#   'uTime': '1698292261465'},
#  'msg': ''}

# %% [markdown]
# ## 3. 获取全部资产余额列表

# %%
get_balances = okxSPOT.account.get_balances()

get_balances
# Out:
# {'code': '0',
#  'data': {'adjEq': '',
#   'borrowFroz': '',
#   'details': [{'availBal': '97.84739206617034',
#     'availEq': '97.84739206617034',
#     'borrowFroz': '',
#     'cashBal': '97.84739206617034',
#     'ccy': 'USDT',
#     'crossLiab': '',
#     'disEq': '97.88066017947284',
#     'eq': '97.84739206617034',
#     'eqUsd': '97.88066017947284',
#     'fixedBal': '0',
#     'frozenBal': '0',
#     'interest': '',
#     'isoEq': '0',
#     'isoLiab': '',
#     'isoUpl': '0',
#     'liab': '',
#     'maxLoan': '',
#     'mgnRatio': '',
#     'notionalLever': '0',
#     'ordFrozen': '0',
#     'spotInUseAmt': '',
#     'spotIsoBal': '0',
#     'stgyEq': '0',
#     'twap': '0',
#     'uTime': '1698292242158',
#     'upl': '0',
#     'uplLiab': ''},
#    {'availBal': '5.645662641',
#     'availEq': '5.645662641',
#     'borrowFroz': '',
#     'cashBal': '5.645662641',
#     'ccy': 'MANA',
#     'crossLiab': '',
#     'disEq': '1.79769189814722',
#     'eq': '5.645662641',
# ...

# %% [markdown]
# ## 4. 获取全部资产余额字典

# %%
get_balancesMap = okxSPOT.account.get_balancesMap()

get_balancesMap
# Out:
# {'code': '0',
#  'data': {'adjEq': '',
#   'borrowFroz': '',
#   'details': {'USDT': {'availBal': '97.84739206617034',
#     'availEq': '97.84739206617034',
#     'borrowFroz': '',
#     'cashBal': '97.84739206617034',
#     'ccy': 'USDT',
#     'crossLiab': '',
#     'disEq': '97.88066017947284',
#     'eq': '97.84739206617034',
#     'eqUsd': '97.88066017947284',
#     'fixedBal': '0',
#     'frozenBal': '0',
#     'interest': '',
#     'isoEq': '0',
#     'isoLiab': '',
#     'isoUpl': '0',
#     'liab': '',
#     'maxLoan': '',
#     'mgnRatio': '',
#     'notionalLever': '0',
#     'ordFrozen': '0',
#     'spotInUseAmt': '',
#     'spotIsoBal': '0',
#     'stgyEq': '0',
#     'twap': '0',
#     'uTime': '1698292242158',
#     'upl': '0',
#     'uplLiab': ''},
#    'MANA': {'availBal': '5.645662641',
#     'availEq': '5.645662641',
#     'borrowFroz': '',
#     'cashBal': '5.645662641',
#     'ccy': 'MANA',
#     'crossLiab': '',
#     'disEq': '1.79769189814722',
# ...

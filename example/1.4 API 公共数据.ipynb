# %%
from okx.api import Public

# %%
public = Public(
    # 不需要秘钥
    # 实盘：0，虚拟盘：1
    flag='0',
    # 使用http和https代理，proxies={'http':'xxxxx','https:':'xxxxx'}，通requests中的proxies参数规则相同
    proxies={},
    # 转发：需搭建转发服务器，可参考：https://github.com/pyted/okx_resender
    proxy_host=None, 
)

# %% [markdown]
# ## 1. 获取交易产品基础信息
#
# 这个接口可以用于价格与数量圆整，币张转换

# %%
instruments_result = public.get_instruments(instType='SWAP')
instruments_result
# Out:
# {'code': '0',
#  'data': [{'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '100',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'BTC-USD',
#    'instId': 'BTC-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '125',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '30000',
#    'maxStopSz': '30000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'BTC',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.1',
#    'uly': 'BTC-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'ETH-USD',
#    'instId': 'ETH-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '125',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '300000',
#    'maxStopSz': '300000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'ETH',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': 'ETH-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'LTC-USD',
#    'instId': 'LTC-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '55000',
#    'maxStopSz': '55000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'LTC',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': 'LTC-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'XRP-USD',
#    'instId': 'XRP-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '40000',
#    'maxStopSz': '40000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'XRP',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': 'XRP-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'BCH-USD',
#    'instId': 'BCH-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '30000',
#    'maxStopSz': '30000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'BCH',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': 'BCH-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'SOL-USD',
#    'instId': 'SOL-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1637833825000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '12000',
#    'maxStopSz': '12000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'SOL',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'SOL-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'FIL-USD',
#    'instId': 'FIL-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '15000',
#    'maxStopSz': '15000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'FIL',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'FIL-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'LINK-USD',
#    'instId': 'LINK-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '20000',
#    'maxStopSz': '20000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'LINK',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'LINK-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': '1INCH-USD',
#    'instId': '1INCH-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1617959702000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '4000',
#    'maxStopSz': '4000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': '1INCH',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': '1INCH-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'ADA-USD',
#    'instId': 'ADA-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '10000',
#    'maxStopSz': '10000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'ADA',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': 'ADA-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'ALGO-USD',
#    'instId': 'ALGO-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '10000',
#    'maxStopSz': '10000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'ALGO',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': 'ALGO-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'ATOM-USD',
#    'instId': 'ATOM-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '10000',
#    'maxStopSz': '10000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'ATOM',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'ATOM-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'AVAX-USD',
#    'instId': 'AVAX-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1637833836000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '10000',
#    'maxStopSz': '10000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'AVAX',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'AVAX-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'BSV-USD',
#    'instId': 'BSV-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '20000',
#    'maxStopSz': '20000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'BSV',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': 'BSV-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'CRV-USD',
#    'instId': 'CRV-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '10000',
#    'maxStopSz': '10000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'CRV',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'CRV-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'DASH-USD',
#    'instId': 'DASH-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '10000',
#    'maxStopSz': '10000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'DASH',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': 'DASH-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'DOGE-USD',
#    'instId': 'DOGE-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1612263452000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '30000',
#    'maxStopSz': '30000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'DOGE',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': 'DOGE-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'DOT-USD',
#    'instId': 'DOT-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '12000',
#    'maxStopSz': '12000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'DOT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'DOT-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'EOS-USD',
#    'instId': 'EOS-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611833669000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '30000',
#    'maxStopSz': '30000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'EOS',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'EOS-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'ETC-USD',
#    'instId': 'ETC-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '20000',
#    'maxStopSz': '20000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'ETC',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'ETC-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'GRT-USD',
#    'instId': 'GRT-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1617959702000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '7000',
#    'maxStopSz': '7000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'GRT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': 'GRT-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'KSM-USD',
#    'instId': 'KSM-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1617959702000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '10000',
#    'maxStopSz': '10000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'KSM',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': 'KSM-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'MANA-USD',
#    'instId': 'MANA-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1637833854000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '10000',
#    'maxStopSz': '10000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'MANA',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'MANA-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'NEO-USD',
#    'instId': 'NEO-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '10000',
#    'maxStopSz': '10000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'NEO',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'NEO-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'SAND-USD',
#    'instId': 'SAND-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1637833844000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '10000',
#    'maxStopSz': '10000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'SAND',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'SAND-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'SUSHI-USD',
#    'instId': 'SUSHI-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '10000',
#    'maxStopSz': '10000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'SUSHI',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'SUSHI-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'THETA-USD',
#    'instId': 'THETA-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '10000',
#    'maxStopSz': '10000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'THETA',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'THETA-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'TRX-USD',
#    'instId': 'TRX-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '15000',
#    'maxStopSz': '15000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'TRX',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': 'TRX-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'UNI-USD',
#    'instId': 'UNI-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '10000',
#    'maxStopSz': '10000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'UNI',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'UNI-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'XLM-USD',
#    'instId': 'XLM-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '10000',
#    'maxStopSz': '10000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'XLM',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': 'XLM-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'XMR-USD',
#    'instId': 'XMR-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '10000',
#    'maxStopSz': '10000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'XMR',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': 'XMR-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'YFI-USD',
#    'instId': 'YFI-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '10000',
#    'maxStopSz': '10000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'YFI',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '1',
#    'uly': 'YFI-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'inverse',
#    'ctVal': '10',
#    'ctValCcy': 'USD',
#    'expTime': '',
#    'instFamily': 'ZEC-USD',
#    'instId': 'ZEC-USD-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '10000',
#    'maxStopSz': '10000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'ZEC',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': 'ZEC-USD'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '0.01',
#    'ctValCcy': 'BTC',
#    'expTime': '',
#    'instFamily': 'BTC-USDT',
#    'instId': 'BTC-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '125',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '12000',
#    'maxStopSz': '12000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.1',
#    'uly': 'BTC-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '0.1',
#    'ctValCcy': 'ETH',
#    'expTime': '',
#    'instFamily': 'ETH-USDT',
#    'instId': 'ETH-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '125',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '20000',
#    'maxStopSz': '20000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': 'ETH-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1',
#    'ctValCcy': 'LTC',
#    'expTime': '',
#    'instFamily': 'LTC-USDT',
#    'instId': 'LTC-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '10000',
#    'maxStopSz': '10000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': 'LTC-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '100',
#    'ctValCcy': 'XRP',
#    'expTime': '',
#    'instFamily': 'XRP-USDT',
#    'instId': 'XRP-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '15000',
#    'maxStopSz': '15000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': 'XRP-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '0.1',
#    'ctValCcy': 'BCH',
#    'expTime': '',
#    'instFamily': 'BCH-USDT',
#    'instId': 'BCH-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '20000',
#    'maxStopSz': '20000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': 'BCH-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1',
#    'ctValCcy': 'SOL',
#    'expTime': '',
#    'instFamily': 'SOL-USDT',
#    'instId': 'SOL-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '15000',
#    'maxStopSz': '15000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'SOL-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '10000000',
#    'ctValCcy': 'PEPE',
#    'expTime': '',
#    'instFamily': 'PEPE-USDT',
#    'instId': 'PEPE-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1683084339000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '25000',
#    'maxStopSz': '25000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0000000001',
#    'uly': 'PEPE-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '0.1',
#    'ctValCcy': 'TRB',
#    'expTime': '',
#    'instFamily': 'TRB-USDT',
#    'instId': 'TRB-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '28000',
#    'maxStopSz': '28000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'TRB-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '0.1',
#    'ctValCcy': 'FIL',
#    'expTime': '',
#    'instFamily': 'FIL-USDT',
#    'instId': 'FIL-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '600000',
#    'maxStopSz': '600000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'FIL-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1',
#    'ctValCcy': 'LINK',
#    'expTime': '',
#    'instFamily': 'LINK-USDT',
#    'instId': 'LINK-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '55000',
#    'maxStopSz': '55000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'LINK-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '100000',
#    'ctValCcy': 'STARL',
#    'expTime': '',
#    'instFamily': 'STARL-USDT',
#    'instId': 'STARL-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1636113018000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '30000',
#    'maxStopSz': '30000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0000000001',
#    'uly': 'STARL-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1',
#    'ctValCcy': '1INCH',
#    'expTime': '',
#    'instFamily': '1INCH-USDT',
#    'instId': '1INCH-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '130000',
#    'maxStopSz': '130000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': '1INCH-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '0.1',
#    'ctValCcy': 'AAVE',
#    'expTime': '',
#    'instFamily': 'AAVE-USDT',
#    'instId': 'AAVE-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '15000',
#    'maxStopSz': '15000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': 'AAVE-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '100',
#    'ctValCcy': 'ADA',
#    'expTime': '',
#    'instFamily': 'ADA-USDT',
#    'instId': 'ADA-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '10000',
#    'maxStopSz': '10000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': 'ADA-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1',
#    'ctValCcy': 'AGLD',
#    'expTime': '',
#    'instFamily': 'AGLD-USDT',
#    'instId': 'AGLD-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1631008650000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '54000',
#    'maxStopSz': '54000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'AGLD-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '10000000000',
#    'ctValCcy': 'AIDOGE',
#    'expTime': '',
#    'instFamily': 'AIDOGE-USDT',
#    'instId': 'AIDOGE-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '10',
#    'listTime': '1683084972000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '15000',
#    'maxStopSz': '15000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0000000000001',
#    'uly': 'AIDOGE-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '10',
#    'ctValCcy': 'ALGO',
#    'expTime': '',
#    'instFamily': 'ALGO-USDT',
#    'instId': 'ALGO-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '55000',
#    'maxStopSz': '55000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': 'ALGO-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1',
#    'ctValCcy': 'ALPHA',
#    'expTime': '',
#    'instFamily': 'ALPHA-USDT',
#    'instId': 'ALPHA-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1616057942000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '500000',
#    'maxStopSz': '500000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': 'ALPHA-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1',
#    'ctValCcy': 'ANT',
#    'expTime': '',
#    'instFamily': 'ANT-USDT',
#    'instId': 'ANT-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '15000',
#    'maxStopSz': '15000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'ANT-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '0.1',
#    'ctValCcy': 'APE',
#    'expTime': '',
#    'instFamily': 'APE-USDT',
#    'instId': 'APE-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1647522059000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '420000',
#    'maxStopSz': '420000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'APE-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1',
#    'ctValCcy': 'API3',
#    'expTime': '',
#    'instFamily': 'API3-USDT',
#    'instId': 'API3-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1646297716000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '14000',
#    'maxStopSz': '14000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'API3-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1',
#    'ctValCcy': 'APT',
#    'expTime': '',
#    'instFamily': 'APT-USDT',
#    'instId': 'APT-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1666142328000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '55000',
#    'maxStopSz': '55000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'APT-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '0.1',
#    'ctValCcy': 'AR',
#    'expTime': '',
#    'instFamily': 'AR-USDT',
#    'instId': 'AR-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1676357067000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '90000',
#    'maxStopSz': '90000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'AR-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '10',
#    'ctValCcy': 'ARB',
#    'expTime': '',
#    'instFamily': 'ARB-USDT',
#    'instId': 'ARB-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1679580094000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '30000',
#    'maxStopSz': '30000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'ARB-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1',
#    'ctValCcy': 'ATOM',
#    'expTime': '',
#    'instFamily': 'ATOM-USDT',
#    'instId': 'ATOM-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '20000',
#    'maxStopSz': '20000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'ATOM-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1',
#    'ctValCcy': 'AVAX',
#    'expTime': '',
#    'instFamily': 'AVAX-USDT',
#    'instId': 'AVAX-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '15000',
#    'maxStopSz': '15000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'AVAX-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '0.1',
#    'ctValCcy': 'AXS',
#    'expTime': '',
#    'instFamily': 'AXS-USDT',
#    'instId': 'AXS-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1627462698000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '150000',
#    'maxStopSz': '150000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'AXS-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '0.1',
#    'ctValCcy': 'BADGER',
#    'expTime': '',
#    'instFamily': 'BADGER-USDT',
#    'instId': 'BADGER-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611925859000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '48000',
#    'maxStopSz': '48000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'BADGER-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '0.1',
#    'ctValCcy': 'BAL',
#    'expTime': '',
#    'instFamily': 'BAL-USDT',
#    'instId': 'BAL-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '54000',
#    'maxStopSz': '54000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'BAL-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1',
#    'ctValCcy': 'BAND',
#    'expTime': '',
#    'instFamily': 'BAND-USDT',
#    'instId': 'BAND-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '30000',
#    'maxStopSz': '30000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'BAND-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '10',
#    'ctValCcy': 'BAT',
#    'expTime': '',
#    'instFamily': 'BAT-USDT',
#    'instId': 'BAT-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '23000',
#    'maxStopSz': '23000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'BAT-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1',
#    'ctValCcy': 'BICO',
#    'expTime': '',
#    'instFamily': 'BICO-USDT',
#    'instId': 'BICO-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '20',
#    'listTime': '1639032617000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '33000',
#    'maxStopSz': '33000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'BICO-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '10',
#    'ctValCcy': 'BIGTIME',
#    'expTime': '',
#    'instFamily': 'BIGTIME-USDT',
#    'instId': 'BIGTIME-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1697112257000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '50000',
#    'maxStopSz': '50000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': 'BIGTIME-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '10',
#    'ctValCcy': 'BLUR',
#    'expTime': '',
#    'instFamily': 'BLUR-USDT',
#    'instId': 'BLUR-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1676427979000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '25000',
#    'maxStopSz': '25000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'BLUR-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '0.01',
#    'ctValCcy': 'BNB',
#    'expTime': '',
#    'instFamily': 'BNB-USDT',
#    'instId': 'BNB-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1671778428000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '100000',
#    'maxStopSz': '100000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': 'BNB-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '10',
#    'ctValCcy': 'BNT',
#    'expTime': '',
#    'instFamily': 'BNT-USDT',
#    'instId': 'BNT-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '4400',
#    'maxStopSz': '4400',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'BNT-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1',
#    'ctValCcy': 'BSV',
#    'expTime': '',
#    'instFamily': 'BSV-USDT',
#    'instId': 'BSV-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '1000000.0000000000000000',
#    'maxLmtSz': '1000000',
#    'maxMktSz': '3000',
#    'maxStopSz': '3000',
#    'maxTriggerSz': '1000000.0000000000000000',
#    'maxTwapSz': '1000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': 'BSV-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1',
#    'ctValCcy': 'CELO',
#    'expTime': '',
#    'instFamily': 'CELO-USDT',
#    'instId': 'CELO-USDT-SWAP',
#    'instType': 'SWAP',
# ...
#    'maxStopSz': '4000',
#    'maxTriggerSz': '1000000.0000000000000000',
#    'maxTwapSz': '1000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': 'TRX-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '0.1',
#    'ctValCcy': 'UMA',
#    'expTime': '',
#    'instFamily': 'UMA-USDT',
#    'instId': 'UMA-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '150000',
#    'maxStopSz': '150000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'UMA-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1',
#    'ctValCcy': 'UNI',
#    'expTime': '',
#    'instFamily': 'UNI-USDT',
#    'instId': 'UNI-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '30000',
#    'maxStopSz': '30000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'UNI-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '10',
#    'ctValCcy': 'USDC',
#    'expTime': '',
#    'instFamily': 'USDC-USDT',
#    'instId': 'USDC-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1678602102000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '10000',
#    'maxStopSz': '10000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'USDC-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '100',
#    'ctValCcy': 'USTC',
#    'expTime': '',
#    'instFamily': 'USTC-USDT',
#    'instId': 'USTC-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1667458491000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '25000',
#    'maxStopSz': '25000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': 'USTC-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1000',
#    'ctValCcy': 'VRA',
#    'expTime': '',
#    'instFamily': 'VRA-USDT',
#    'instId': 'VRA-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '20',
#    'listTime': '1696574982000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '15000',
#    'maxStopSz': '15000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.000001',
#    'uly': 'VRA-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1',
#    'ctValCcy': 'WAVES',
#    'expTime': '',
#    'instFamily': 'WAVES-USDT',
#    'instId': 'WAVES-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '45000',
#    'maxStopSz': '45000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'WAVES-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '100',
#    'ctValCcy': 'WAXP',
#    'expTime': '',
#    'instFamily': 'WAXP-USDT',
#    'instId': 'WAXP-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1697685018000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '15000',
#    'maxStopSz': '15000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': 'WAXP-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1',
#    'ctValCcy': 'WLD',
#    'expTime': '',
#    'instFamily': 'WLD-USDT',
#    'instId': 'WLD-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1690199688000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '50000',
#    'maxStopSz': '50000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'WLD-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '10',
#    'ctValCcy': 'WOO',
#    'expTime': '',
#    'instFamily': 'WOO-USDT',
#    'instId': 'WOO-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1676357067000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '50000',
#    'maxStopSz': '50000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'WOO-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '100',
#    'ctValCcy': 'WSM',
#    'expTime': '',
#    'instFamily': 'WSM-USDT',
#    'instId': 'WSM-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1696564064000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '20000',
#    'maxStopSz': '20000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': 'WSM-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '0.01',
#    'ctValCcy': 'XCH',
#    'expTime': '',
#    'instFamily': 'XCH-USDT',
#    'instId': 'XCH-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1620460471000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '44000',
#    'maxStopSz': '44000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': 'XCH-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '100',
#    'ctValCcy': 'XLM',
#    'expTime': '',
#    'instFamily': 'XLM-USDT',
#    'instId': 'XLM-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '9000',
#    'maxStopSz': '9000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': 'XLM-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '0.1',
#    'ctValCcy': 'XMR',
#    'expTime': '',
#    'instFamily': 'XMR-USDT',
#    'instId': 'XMR-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '6500',
#    'maxStopSz': '6500',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': 'XMR-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1',
#    'ctValCcy': 'XTZ',
#    'expTime': '',
#    'instFamily': 'XTZ-USDT',
#    'instId': 'XTZ-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '70000',
#    'maxStopSz': '70000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'XTZ-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '0.0001',
#    'ctValCcy': 'YFI',
#    'expTime': '',
#    'instFamily': 'YFI-USDT',
#    'instId': 'YFI-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '150000',
#    'maxStopSz': '150000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '1',
#    'uly': 'YFI-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '0.001',
#    'ctValCcy': 'YFII',
#    'expTime': '',
#    'instFamily': 'YFII-USDT',
#    'instId': 'YFII-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '50000',
#    'maxStopSz': '50000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.1',
#    'uly': 'YFII-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1',
#    'ctValCcy': 'YGG',
#    'expTime': '',
#    'instFamily': 'YGG-USDT',
#    'instId': 'YGG-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1628240523000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '110000',
#    'maxStopSz': '110000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'YGG-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '0.1',
#    'ctValCcy': 'ZEC',
#    'expTime': '',
#    'instFamily': 'ZEC-USDT',
#    'instId': 'ZEC-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '25000',
#    'maxStopSz': '25000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': 'ZEC-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '1',
#    'ctValCcy': 'ZEN',
#    'expTime': '',
#    'instFamily': 'ZEN-USDT',
#    'instId': 'ZEN-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '2500',
#    'maxStopSz': '2500',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.001',
#    'uly': 'ZEN-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '100',
#    'ctValCcy': 'ZIL',
#    'expTime': '',
#    'instFamily': 'ZIL-USDT',
#    'instId': 'ZIL-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '35000',
#    'maxStopSz': '35000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.00001',
#    'uly': 'ZIL-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '10',
#    'ctValCcy': 'ZRX',
#    'expTime': '',
#    'instFamily': 'ZRX-USDT',
#    'instId': 'ZRX-USDT-SWAP',
#    'instType': 'SWAP',
#    'lever': '50',
#    'listTime': '1611916828000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '21000',
#    'maxStopSz': '21000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDT',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.0001',
#    'uly': 'ZRX-USDT'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '0.0001',
#    'ctValCcy': 'BTC',
#    'expTime': '',
#    'instFamily': 'BTC-USDC',
#    'instId': 'BTC-USDC-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1666076190000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '85000',
#    'maxStopSz': '85000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDC',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.1',
#    'uly': 'BTC-USDC'},
#   {'alias': '',
#    'baseCcy': '',
#    'category': '1',
#    'ctMult': '1',
#    'ctType': 'linear',
#    'ctVal': '0.001',
#    'ctValCcy': 'ETH',
#    'expTime': '',
#    'instFamily': 'ETH-USDC',
#    'instId': 'ETH-USDC-SWAP',
#    'instType': 'SWAP',
#    'lever': '75',
#    'listTime': '1666076197000',
#    'lotSz': '1',
#    'maxIcebergSz': '100000000.0000000000000000',
#    'maxLmtSz': '100000000',
#    'maxMktSz': '120000',
#    'maxStopSz': '120000',
#    'maxTriggerSz': '100000000.0000000000000000',
#    'maxTwapSz': '100000000.0000000000000000',
#    'minSz': '1',
#    'optType': '',
#    'quoteCcy': '',
#    'settleCcy': 'USDC',
#    'state': 'live',
#    'stk': '',
#    'tickSz': '0.01',
#    'uly': 'ETH-USDC'}],
#  'msg': ''}

# %% [markdown]
# ## 2. 获取永续合约当前资金费率

# %%
funding_rate_result = public.get_funding_rate(instId='BTC-USDT-SWAP')
funding_rate_result
# Out:
# {'code': '0',
#  'data': [{'fundingRate': '0.0000566970196602',
#    'fundingTime': '1698307200000',
#    'instId': 'BTC-USDT-SWAP',
#    'instType': 'SWAP',
#    'nextFundingRate': '0.0001865656423996',
#    'nextFundingTime': '1698336000000'}],
#  'msg': ''}
